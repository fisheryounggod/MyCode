# %% [markdown]
# ## 作业
# 将课本P93页3.1、3.2、3.3的**程序代码及运行结果**分别截图保存，作为第2次作业的附件（一共2个附件），发送到作业邮箱zhangduzhong@swufe.edu.cn。<br><br><b><font color=red>邮件标题必须类似于：Python作业2_1233456。</font>其中123456需要替换成你的学号。<br><br><b><font color=red>邮件标题必须类似于：Python作业2_1233456。</font>其中123456需要替换成你的学号。<br><br><b><font color=red>邮件标题必须类似于：Python作业2_1233456。</font>其中123456需要替换成你的学号。

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 3.1
xuehao_and_xingming = '学号：219020204138 | 姓名：杨雄飞'
print(xuehao_and_xingming)
weight0 = int(input('你当前的体重(kg)：'))
n = 10
for i in range(1, 11):
    weight = weight0+i*0.5
    print("第{:>2}年你在地球上体重为：{:>5} Kg".format(i, weight), end='|')
    print("第{:>2}年你在月球上体重为：{:>5} Kg".format(i, round(weight*0.165, 2)))
# Out:
# 学号：219020204138 | 姓名：杨雄飞
# 你当前的体重(kg)：60
# 第 1年你在地球上体重为： 60.5 Kg|第 1年你在月球上体重为： 9.98 Kg
# 第 2年你在地球上体重为： 61.0 Kg|第 2年你在月球上体重为：10.07 Kg
# 第 3年你在地球上体重为： 61.5 Kg|第 3年你在月球上体重为：10.15 Kg
# 第 4年你在地球上体重为： 62.0 Kg|第 4年你在月球上体重为：10.23 Kg
# 第 5年你在地球上体重为： 62.5 Kg|第 5年你在月球上体重为：10.31 Kg
# 第 6年你在地球上体重为： 63.0 Kg|第 6年你在月球上体重为： 10.4 Kg
# 第 7年你在地球上体重为： 63.5 Kg|第 7年你在月球上体重为：10.48 Kg
# 第 8年你在地球上体重为： 64.0 Kg|第 8年你在月球上体重为：10.56 Kg
# 第 9年你在地球上体重为： 64.5 Kg|第 9年你在月球上体重为：10.64 Kg
# 第10年你在地球上体重为： 65.0 Kg|第10年你在月球上体重为：10.72 Kg

# %%
# 3.2
xuehao_and_xingming = '学号：219020204138 | 姓名：杨雄飞'
print(xuehao_and_xingming)
capability = 1
for i in range(1, 366):
    if i % 7 in [1, 2, 3]:
        capability = capability
    elif i % 7 in [0, 4, 5, 6]:
        capability = (1+0.01)*capability
print("连续学习365天后的能力为：", capability)
# Out:
# 学号：219020204138 | 姓名：杨雄飞
# 连续学习365天后的能力为： 7.922198989348805

# %%
# 3.3-1
xuehao_and_xingming = '学号：219020204138 | 姓名：杨雄飞'
print(xuehao_and_xingming)
N = int(input("每学几天休息一天："))+1
capability = 1
for i in range(1, 366):
    if i % N == 0:
        capability = capability
    elif i % N % 7 in [1, 2, 3]:
        capability = capability
    elif i % N % 7 in [4, 5, 6, 0]:
        capability = (1+0.01)*capability
print("每{}天休息一天，学习{}天后的能力为{}".format(N, i, capability))
# Out:
# 学号：219020204138 | 姓名：杨雄飞
# 每学几天休息一天：10
# 每11天休息一天，学习365天后的能力为3.7189585619251337

# %%
# 3.3-2
xuehao_and_xingming = '学号：219020204138 | 姓名：杨雄飞'
print(xuehao_and_xingming)
N = int(input("每学几天休息一天："))+1
capability = 1
for i in range(1, 366):
    if i % N == 0:
        capability = capability
    elif i % N % 7 in [1, 2, 3]:
        capability = capability
    elif i % N % 7 in [4, 5, 6, 0]:
        capability = (1+0.01)*capability
print("每{}天休息一天，学习{}天后的能力为{}".format(N, i, capability))
# Out:
# 学号：219020204138 | 姓名：杨雄飞
# 每学几天休息一天：15
# 每16天休息一天，学习365天后的能力为6.177480771011442
