// %% [markdown]
// ## Stata 测试

// %%
dis 1+1
// Out:
// 2

// %%
sysuse auto,clear
reg price weight
// Out:
// (1978 Automobile Data)
//
//
//       Source |       SS           df       MS      Number of obs   =        74
// -------------+----------------------------------   F(1, 72)        =     29.42
//        Model |   184233937         1   184233937   Prob > F        =    0.0000
//     Residual |   450831459        72  6261548.04   R-squared       =    0.2901
// -------------+----------------------------------   Adj R-squared   =    0.2802
//        Total |   635065396        73  8699525.97   Root MSE        =    2502.3
//
// ------------------------------------------------------------------------------
//        price |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//       weight |      2.044      0.377     5.42   0.000        1.293       2.795
//        _cons |     -6.707   1174.430    -0.01   0.995    -2347.890    2334.475
// ...

// %%
scatter price weight
// Out:
// This front-end cannot display the desired image type.

// %%
import ipystata
from ipystata.config import config_stata
config_stata("C:\Program Files\Stata16\StataMP-64.exe")

// %%
%%stata
sysuse auto,clear
scatter price weight
// Out:
// (1978 Automobile Data)

// %%
%%stata -gr
use auto, clear
graph twoway scatter price weight
// Out:
// file auto.dta not found
// r(601);

// %% [markdown]
// ## Stata 调用 R

// %% [markdown]
// > 需要开启管理员权限

// %%
cd "C:\windows"
// Out:
// C:\windows

// %%
rcall:pi
// Out:
// [1] 3.141593

// %%
rcall:st<-"Hello Stata & R"
dis r(st)
// Out:
// Hello Stata & R

// %% [markdown]
// ## Stata 调用Python

// %%
python
import math
print(math.pi)
end
// Out:
// ----------------------------------------------- python (type end to exit) ------
//
// >>> print(math.pi)
// 3.141592653589793
// >>> end
// --------------------------------------------------------------------------------
