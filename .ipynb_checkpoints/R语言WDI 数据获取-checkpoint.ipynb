# %%
library('WDI')

# %%
WDIsearch('gdp')
# Out:
#       indicator
#  [1,] BX.TRF.PWKR.GD.ZS
#  [2,] BX.TRF.PWKR.DT.GD.ZS
#  [3,] BX.TRF.MGR.DT.GD.ZS
#  [4,] BX.KLT.DINV.WD.GD.ZS
#  [5,] BX.KLT.DINV.DT.GD.ZS
#  [6,] BX.GSR.MRCH.ZS
#  [7,] 6.0.GDPpc_constant
#  [8,] 6.0.GDP_usd
#  [9,] 6.0.GDP_growth
# [10,] 6.0.GDP_current
# [11,] 5.51.01.10.gdp
# [12,] SF.TRN.RAIL.KM.ZS
# [13,] SE.XPD.TOTL.GD.ZS
# [14,] SE.XPD.TERT.PC.ZS
# [15,] SE.XPD.TERT.GDP.ZS
# [16,] SE.XPD.SECO.PC.ZS
# [17,] SE.XPD.SECO.GDP.ZS
# [18,] SE.XPD.PRIM.PC.ZS
# [19,] SE.XPD.PRIM.GDP.ZS
# [20,] SE.XPD.EDUC.ZS
# [21,] NY.GEN.SVNG.GD.ZS
# [22,] NY.GEN.NDOM.GD.ZS
# [23,] NY.GEN.DNGY.GD.ZS
# [24,] NY.GEN.DMIN.GD.ZS
# [25,] NY.GEN.DKAP.GD.ZS
# [26,] NY.GEN.DFOR.GD.ZS
# [27,] NY.GEN.DCO2.GD.ZS
# [28,] NY.GEN.AEDU.GD.ZS
# [29,] NY.GDS.TOTL.ZS
# [30,] NY.GDP.TOTL.RT.ZS
# [31,] ⋮
# [32,] UIS.XGDP.1.FSGOV.FFNTR
# [33,] UIS.XGDP.1.FSGOV
# [34,] UIS.XGDP.02.FSGOV.FFNTR
# [35,] UIS.XGDP.0.FSGOV
# [36,] TG.VAL.TOTL.GG.ZS
# [37,] TG.VAL.TOTL.GD.ZS
# [38,] TG.VAL.TOTL.GD.PP.ZS
# ...

# %%
WDIsearch('bop')
# Out:
#       indicator
#  [1,] BX.TRF.XOKA.CD
#  [2,] BX.TRF.PWKR.CD
#  [3,] BX.TRF.PRVT.CD
#  [4,] BX.TRF.OFDC.CD
#  [5,] BX.TRF.CURR.CD
#  [6,] BX.SVN.TOTL.CD
#  [7,] BX.SVF.TOTL.CD
#  [8,] BX.PEF.TOTL.CD.WD
#  [9,] BX.KLT.DINV.CD.WD
# [10,] BX.KLT.DINV.CD
# [11,] BX.GSR.TRVL.ZS
# [12,] BX.GSR.TRVL.CD
# [13,] BX.GSR.TRAN.ZS
# [14,] BX.GSR.TRAN.CD
# [15,] BX.GSR.TOTL.CD
# [16,] BX.GSR.ROYL.CD
# [17,] BX.GSR.OSRV.CD
# [18,] BX.GSR.NFSV.CD
# [19,] BX.GSR.MRCH.ZS
# [20,] BX.GSR.MRCH.CD
# [21,] BX.GSR.INSU.CD
# [22,] BX.GSR.INSF.ZS
# [23,] BX.GSR.INCL.CD
# [24,] BX.GSR.GNFS.CD
# [25,] BX.GSR.FINS.CD
# [26,] BX.GSR.FCTY.CD
# [27,] BX.GSR.COMM.CD
# [28,] BX.GSR.CMCP.ZS
# [29,] BX.GSR.CCIS.ZS
# [30,] BX.GSR.CCIS.CD
# [31,] ⋮
# [32,] BN.CAB.XOKA.CD
# [33,] BN.CAB.IOTR.CD
# [34,] BN.CAB.FUND.CD
# [35,] BM.TRF.XOKA.CD
# [36,] BM.TRF.PWKR.CD
# [37,] BM.TRF.PRVT.CD
# [38,] BM.TRF.OFDC.CD
# [39,] BM.TRF.CURR.CD
# [40,] BM.SVN.TOTL.CD
# [41,] BM.SVF.TOTL.CD
# [42,] BM.KLT.DINV.CD.WD
# ...

# %%
WDI(indicator='BN.CAB.XOKA.GD.ZS', country=c('CN'), start=1982, end=2019) #Current account balance (% of GDP)
# Out:
#    iso2c country BN.CAB.XOKA.GD.ZS year
# 1  CN    China           NA        2019
# 2  CN    China    0.3607513        2018
# 3  CN    China    1.6067592        2017
# 4  CN    China    1.8154463        2016
# 5  CN    China    2.7612299        2015
# 6  CN    China    2.2613011        2014
# 7  CN    China    1.5485650        2013
# 8  CN    China    2.5244482        2012
# 9  CN    China    1.8022479        2011
# 10 CN    China    3.9067515        2010
# 11 CN    China    4.7681450        2009
# 12 CN    China    9.1541234        2008
# 13 CN    China    9.9478483        2007
# 14 CN    China    8.4241257        2006
# 15 CN    China    5.7909216        2005
# 16 CN    China    3.5257660        2004
# 17 CN    China    2.5930190        2003
# 18 CN    China    2.4087585        2002
# 19 CN    China    1.2991680        2001
# 20 CN    China    1.6938486        2000
# 21 CN    China    1.9300779        1999
# 22 CN    China    3.0583753        1998
# ...

# %%
WDI(indicator='6.0.GDP_current', country=c('CN'), start=1982, end=2019) #Current account balance (% of GDP)
# Out:
# Warning message in WDI(indicator = "6.0.GDP_current", country = c("CN"), start = 1982, :
# “Unable to download indicators  6.0.GDP_current”
# Error in 1:nrow(lab): 参数长度为零
# Traceback:
#
# 1. WDI(indicator = "6.0.GDP_current", country = c("CN"), start = 1982,
#  .     end = 2019)

# %%
l=WDIsearch('bop')

# %%
l
# Out:
#       indicator
#  [1,] BX.TRF.XOKA.CD
#  [2,] BX.TRF.PWKR.CD
#  [3,] BX.TRF.PRVT.CD
#  [4,] BX.TRF.OFDC.CD
#  [5,] BX.TRF.CURR.CD
#  [6,] BX.SVN.TOTL.CD
#  [7,] BX.SVF.TOTL.CD
#  [8,] BX.PEF.TOTL.CD.WD
#  [9,] BX.KLT.DINV.CD.WD
# [10,] BX.KLT.DINV.CD
# [11,] BX.GSR.TRVL.ZS
# [12,] BX.GSR.TRVL.CD
# [13,] BX.GSR.TRAN.ZS
# [14,] BX.GSR.TRAN.CD
# [15,] BX.GSR.TOTL.CD
# [16,] BX.GSR.ROYL.CD
# [17,] BX.GSR.OSRV.CD
# [18,] BX.GSR.NFSV.CD
# [19,] BX.GSR.MRCH.ZS
# [20,] BX.GSR.MRCH.CD
# [21,] BX.GSR.INSU.CD
# [22,] BX.GSR.INSF.ZS
# [23,] BX.GSR.INCL.CD
# [24,] BX.GSR.GNFS.CD
# [25,] BX.GSR.FINS.CD
# [26,] BX.GSR.FCTY.CD
# [27,] BX.GSR.COMM.CD
# [28,] BX.GSR.CMCP.ZS
# [29,] BX.GSR.CCIS.ZS
# [30,] BX.GSR.CCIS.CD
# [31,] ⋮
# [32,] BN.CAB.XOKA.CD
# [33,] BN.CAB.IOTR.CD
# [34,] BN.CAB.FUND.CD
# [35,] BM.TRF.XOKA.CD
# [36,] BM.TRF.PWKR.CD
# [37,] BM.TRF.PRVT.CD
# [38,] BM.TRF.OFDC.CD
# [39,] BM.TRF.CURR.CD
# [40,] BM.SVN.TOTL.CD
# [41,] BM.SVF.TOTL.CD
# [42,] BM.KLT.DINV.CD.WD
# ...

# %%
write.csv(l,'./bop.csv')
