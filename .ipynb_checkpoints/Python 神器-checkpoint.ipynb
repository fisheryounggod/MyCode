# %% [markdown]
# ## Black：强大的Python代码格式化工具

# %%
import black

# %% [markdown]
# `black {source_file_or_directory}`

# %%
with open('./text.txt','w') as f:
    f.writelines('print    ("Hello World!") # 打印')

# %%
# !cat text.txt
# Out:
# print    ("Hello World!") # 打印

# %%
# !black text.txt   #终端中运行
# Out:
# reformatted text.txt
# All done! ✨ 🍰 ✨
# 1 file reformatted.

# %%
# !cat text.txt
# Out:
# print("Hello World!")  # 打印

# %% [markdown]
# ## musicbox：Python实现的网易云音乐命令行版本，支持320kbps的高品质音乐

# %%
# !musicbox
# Out:
# Traceback (most recent call last):
#   File "/Users/mac/.pyenv/versions/3.7.3/bin/musicbox", line 5, in <module>
#     from NEMbox.__main__ import start
#   File "/Users/mac/.pyenv/versions/3.7.3/lib/python3.7/site-packages/NEMbox/__main__.py", line 9, in <module>
#     import curses
#   File "/Users/mac/.pyenv/versions/3.7.3/lib/python3.7/curses/__init__.py", line 13, in <module>
#     from _curses import *
# ModuleNotFoundError: No module named '_curses'

# %% [markdown]
# ## akshare:一个简单易用的金融数据接口库

# %% [markdown]
# 实现了对股票、期货、期权、基金、外汇、债券、指数、数字货币等金融产品数据实时和历史数据、衍生数据采集、清洗、落地全流程的开源工具。

# %%
import akshare as ak
ak.get_roll_yield_bar(type_method="date", var="RB", start_day="20200618", end_day="20200820", plot=True,)
# Out:
# /Users/mac/.pyenv/versions/3.7.3/lib/python3.7/site-packages/akshare/futures/futures_roll_yield.py:152: UserWarning: 20200620非交易日
#   warnings.warn("%s非交易日" % date.strftime("%Y%m%d"))
# /Users/mac/.pyenv/versions/3.7.3/lib/python3.7/site-packages/akshare/futures/futures_roll_yield.py:152: UserWarning: 20200621非交易日
#   warnings.warn("%s非交易日" % date.strftime("%Y%m%d"))
# /Users/mac/.pyenv/versions/3.7.3/lib/python3.7/site-packages/akshare/futures/futures_roll_yield.py:152: UserWarning: 20200625非交易日
#   warnings.warn("%s非交易日" % date.strftime("%Y%m%d"))
# /Users/mac/.pyenv/versions/3.7.3/lib/python3.7/site-packages/akshare/futures/futures_roll_yield.py:152: UserWarning: 20200626非交易日
#   warnings.warn("%s非交易日" % date.strftime("%Y%m%d"))
# /Users/mac/.pyenv/versions/3.7.3/lib/python3.7/site-packages/akshare/futures/futures_roll_yield.py:152: UserWarning: 20200627非交易日
#   warnings.warn("%s非交易日" % date.strftime("%Y%m%d"))
# ...

# %% [markdown]
# ## helium:基于 Selenium实现的网页自动化工具

# %%
from helium import *
start_chrome('google.com')
write('helium selenium github')
press(ENTER)

click('mherrmann/selenium')
go_to('github.com/login')
write('1632164730@qq.com', into='username')
write('yxfabc123', into='password')
click('Sign in')

# %%
kill_browser()

# %%
import helium

# %%
dir(helium)
# Out:
# ['ADD',
#  'ALT',
#  'APIImpl',
#  'ARROW_DOWN',
#  'ARROW_LEFT',
#  'ARROW_RIGHT',
#  'ARROW_UP',
#  'Alert',
#  'BACK_SPACE',
#  'Button',
#  'CANCEL',
#  'CLEAR',
#  'COMMAND',
#  'CONTROL',
#  'CheckBox',
#  'ComboBox',
#  'Config',
#  'DECIMAL',
#  'DELETE',
#  'DIVIDE',
#  'DOWN',
#  'END',
#  'ENTER',
#  'EQUALS',
#  'ESCAPE',
#  'F1',
#  'F10',
#  'F11',
#  'F12',
#  'F2',
#  'F3',
#  'F4',
#  'F5',
#  'F6',
#  'F7',
#  'F8',
#  'F9',
#  'GUIElement',
#  'HELP',
#  'HOME',
#  'HTMLElement',
#  'INSERT',
#  'Image',
#  'Keys',
#  'LEFT',
#  'LEFT_ALT',
#  'LEFT_CONTROL',
#  'LEFT_SHIFT',
#  'Link',
#  'ListItem',
#  'META',
#  'MULTIPLY',
#  'NULL',
#  'NUMPAD0',
#  'NUMPAD1',
#  'NUMPAD2',
#  'NUMPAD3',
#  'NUMPAD4',
#  'NUMPAD5',
#  'NUMPAD6',
#  'NUMPAD7',
#  'NUMPAD8',
#  'NUMPAD9',
#  'OrderedDict',
#  'PAGE_DOWN',
#  'PAGE_UP',
#  'PAUSE',
#  'Point',
#  'RETURN',
#  'RIGHT',
#  'RadioButton',
#  'S',
#  'SEMICOLON',
#  'SEPARATOR',
#  'SHIFT',
#  'SPACE',
# ...
