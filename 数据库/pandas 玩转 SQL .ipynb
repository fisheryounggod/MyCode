# %% [markdown]
# ## [sqlite函数大全：](http://suo.im/5DWraE)

# %%
import pandas as pd
from pandasql import sqldf

# %% [markdown]
# 声明全局变量的2种方式
#
# ① 在使用之前，声明该全局变量；

# %%
df1 = pd.read_excel("student.xlsx")
df2 = pd.read_excel("sc.xlsx")
df3 = pd.read_excel("course.xlsx")
df4 = pd.read_excel("teacher.xlsx")

# %%
global df1
global df2
global df3
global df4
query1 = "select * from df1 limit 5"
query2 = "select * from df2 limit 5"
query3 = "select * from df3"
query4 = "select * from df4"

# %%
sqldf(query1)
# Out:
#    sid sname                        sage ssex
# 0    1    赵雷  1990-01-01 00:00:00.000000    男
# 1    2    钱电  1990-12-21 00:00:00.000000    男
# 2    3    孙风  1990-12-20 00:00:00.000000    男
# 3    4    李云  1990-12-06 00:00:00.000000    男
# 4    5    周梅  1991-12-01 00:00:00.000000    女

# %%
sqldf(query2)
# Out:
#    sid  cid  score
# 0    1    1     80
# 1    1    2     90
# 2    1    3     99
# 3    2    1     70
# 4    2    2     60

# %%
sqldf(query3)
# Out:
#    cid cname  tid
# 0    1    语文    2
# 1    2    数学    1
# 2    3    英语    3

# %%
sqldf(query4)
# Out:
#    tid tname
# 0    1    张三
# 1    2    李四
# 2    3    王五

# %% [markdown]
# ② 一次性声明好全局变量；

# %%
df1 = pd.read_excel("student.xlsx")
df2 = pd.read_excel("sc.xlsx")
df3 = pd.read_excel("course.xlsx")
df4 = pd.read_excel("teacher.xlsx")

# %%
pysqldf = lambda q: sqldf(q, globals())  #一次性声明

# %%
query1 = "select * from df1 limit 5"

# %%
query2 = "select * from df2 limit 5"

# %%
query3 = "select * from df3"

# %%
query4 = "select * from df4"

# %%
sqldf(query1)
# Out:
#    sid sname                        sage ssex
# 0    1    赵雷  1990-01-01 00:00:00.000000    男
# 1    2    钱电  1990-12-21 00:00:00.000000    男
# 2    3    孙风  1990-12-20 00:00:00.000000    男
# 3    4    李云  1990-12-06 00:00:00.000000    男
# 4    5    周梅  1991-12-01 00:00:00.000000    女

# %%
sqldf(query2)
# Out:
#    sid  cid  score
# 0    1    1     80
# 1    1    2     90
# 2    1    3     99
# 3    2    1     70
# 4    2    2     60

# %%
sqldf(query3)
# Out:
#    cid cname  tid
# 0    1    语文    2
# 1    2    数学    1
# 2    3    英语    3

# %%
sqldf(query4)
# Out:
#    tid tname
# 0    1    张三
# 1    2    李四
# 2    3    王五

# %% [markdown]
# ## Example

# %%
# 查看sqlite的版本

query1 = """
    select sqlite_version(*)
"""
pysqldf(query1)
# Out:
#   sqlite_version(*)
# 0            3.28.0

# %%
# where筛选

student = pd.read_excel("student.xlsx")
pysqldf = lambda q: sqldf(q, globals())
query1 = """
    select * 
    from student 
    where strftime('%Y-%m-%d',sage) = '1990-01-01'
"""
pysqldf(query1)
# Out:
#    sid sname                        sage ssex
# 0    1    赵雷  1990-01-01 00:00:00.000000    男

# %%
# 多表连接

student = pd.read_excel("student.xlsx")
sc = pd.read_excel("sc.xlsx")


pysqldf = lambda q: sqldf(q, globals())
query2 = """
    select *
    from student s
    join sc on s.sid = sc.sid
"""
pysqldf(query2)
# Out:
#     sid sname                        sage ssex  sid  cid  score
# 0     1    赵雷  1990-01-01 00:00:00.000000    男    1    1     80
# 1     1    赵雷  1990-01-01 00:00:00.000000    男    1    2     90
# 2     1    赵雷  1990-01-01 00:00:00.000000    男    1    3     99
# 3     2    钱电  1990-12-21 00:00:00.000000    男    2    1     70
# 4     2    钱电  1990-12-21 00:00:00.000000    男    2    2     60
# 5     2    钱电  1990-12-21 00:00:00.000000    男    2    3     80
# 6     3    孙风  1990-12-20 00:00:00.000000    男    3    1     80
# 7     3    孙风  1990-12-20 00:00:00.000000    男    3    2     80
# 8     3    孙风  1990-12-20 00:00:00.000000    男    3    3     80
# 9     4    李云  1990-12-06 00:00:00.000000    男    4    1     50
# 10    4    李云  1990-12-06 00:00:00.000000    男    4    2     30
# 11    4    李云  1990-12-06 00:00:00.000000    男    4    3     20
# 12    5    周梅  1991-12-01 00:00:00.000000    女    5    1     76
# 13    5    周梅  1991-12-01 00:00:00.000000    女    5    2     87
# 14    6    吴兰  1992-01-01 00:00:00.000000    女    6    1     31
# 15    6    吴兰  1992-01-01 00:00:00.000000    女    6    3     34
# 16    7    郑竹  1989-01-01 00:00:00.000000    女    7    2     89
# 17    7    郑竹  1989-01-01 00:00:00.000000    女    7    3     98

# %%
# 分组聚合

student = pd.read_excel("student.xlsx")
sc = pd.read_excel("sc.xlsx")


pysqldf = lambda q: sqldf(q, globals())
query2 = """
    select s.sname as 姓名,sum(sc.score) as 总分
    from student s
    join sc on s.sid = sc.sid
    group by s.sname
"""
pysqldf(query2)
# Out:
#    姓名   总分
# 0  吴兰   65
# 1  周梅  163
# 2  孙风  240
# 3  李云  100
# 4  赵雷  269
# 5  郑竹  187
# 6  钱电  210

# %%
# Union 查询

student = pd.read_excel("student.xlsx")
pysqldf = lambda q: sqldf(q, globals())
query1 = """
    select * 
    from student 
    where strftime('%Y-%m',sage) = '1990-01'
    union
    select * 
    from student 
    where strftime('%Y-%m',sage) = '1990-12'
"""
pysqldf(query1)
# Out:
#    sid sname                        sage ssex
# 0    1    赵雷  1990-01-01 00:00:00.000000    男
# 1    2    钱电  1990-12-21 00:00:00.000000    男
# 2    3    孙风  1990-12-20 00:00:00.000000    男
# 3    4    李云  1990-12-06 00:00:00.000000    男
# 4    8    王菊  1990-01-20 00:00:00.000000    女
