# %% [markdown]
# # 第 9 章 可视化

# %%
fig = plt.figure()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
plt.plot(np.random.randn(50).cumsum(),'k--')

# %%
plt.plot(np.random.randn(50).cumsum(),'k--')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
plt.plot(np.random.randn(50).cumsum(),'k--')
ax1.hist(np.random.randn(100),bins=20,color='k',alpha=0.3)
ax2.scatter(np.arange(30),np.arange(30)+3*np.random.randn(30))
ax3.barh(np.arange(10),np.arange(10)+3*np.random.randn(10))        # 横向柱状图
# Out:
# <BarContainer object of 10 artists>

# %%
fig, axes = plt.subplots(2,2)

# %%
fig, axes = plt.subplots(2,2, sharey=True)
axes[0,0].scatter(np.arange(30),np.arange(30)+3*np.random.randn(30));
axes[0,1].hist(np.random.randn(100),bins=20,color='k',alpha=0.3);

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True) 
for i in range(2):     
    for j in range(2):         
        axes[i, j].hist(np.random.randn(500), bins=50, color='k' , alpha=0.5) 
        plt.subplots_adjust(wspace=0, hspace=0)

# %%
fig = plt.figure()
fig.add_subplot(1,1,1)
plt.plot(np.random.randn(1000).cumsum(),'k--')

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum(),'k--')

ticks = ax.set_xticks([0,250,500,750,1000])
# labels = ax.set_xticklabels(np.arange(2000,2020,2),rotation=60,fontsize='large')
labels = ax.set_xticklabels(pd.date_range(start='1/1/2018', periods=5, freq=pd.offsets.MonthEnd(3)))
fig.autofmt_xdate()
ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stages')
# ax.legend(loc='best')
# Out:
# Text(0.5, 0, 'Stages')

# %%
current_date=datetime.strptime(row[0],"%Y-%m-%d")

# %%
data
# Out:
#               AAPL   MSFT    XOM      SPX
# 2003-01-02    7.40  21.11  29.22   909.03
# 2003-01-03    7.45  21.14  29.24   908.59
# 2003-01-06    7.45  21.52  29.96   929.01
# 2003-01-07    7.43  21.93  28.95   922.93
# 2003-01-08    7.28  21.31  28.83   909.93
# ...            ...    ...    ...      ...
# 2011-10-10  388.81  26.94  76.28  1194.89
# 2011-10-11  400.29  27.00  76.27  1195.54
# 2011-10-12  402.19  26.96  77.16  1207.25
# 2011-10-13  408.43  27.18  76.37  1203.66
# 2011-10-14  422.00  27.27  78.11  1224.58
#
# [2214 rows x 4 columns]

# %%
from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

data = pd.read_csv('stock_px.csv',index_col=0,parse_dates = True)
spx = data['SPX']
spx.plot(figsize=(20,12),ax=ax,style='k--',fontsize='large')

crisis_data = [
    (datetime(2007,10,11),'Peak of bull market'),
    (datetime(2008,3,12),'Bear Strearns Fails'),
    (datetime(2008,9,15),'Lehman Bankruptcy')
]

for date, label in crisis_data:    # 多处标注用for循环来写
    ax.annotate(label,xy=(date, spx.asof(date)+75),
               xytext = (date,spx.asof(date)+225),
               arrowprops = dict(facecolor='black',headwidth=4,width=2,
                                headlength =4),
               horizontalalignment='left',verticalalignment='top',fontsize='large')
    
ax.set_xlim(['1/1/2007','1/1/2011'])
ax.set_ylim([600,1800])

ax.set_title("Important dates in the 2008-2009 financial crisis")
# Out:
# Text(0.5, 1.0, 'Important dates in the 2008-2009 financial crisis')

# %%
fig = plt.figure() 
ax = fig.add_subplot(1, 1, 1) 
rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3 ) 
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3) 
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],                    
                   color='g', alpha=0.5) 
ax.add_patch(rect) 
ax.add_patch(circ) 
ax.add_patch(pgon)

# %% [markdown]
# 将图表保存到文件利用plt.savefig可以将当前图表保存到文件。该方法相当于Figure对象的实例方法savefig。例如,要将图表保存为SVG文件,你只需输入:

# %%
plt.savefig('figpath.svg')

# %%
df = pd.DataFrame(np.random.rand(6, 4),              
                  index=['one', 'two', 'three', 'four', 'five', 'six'],              
                  columns=pd.Index(['A', 'B', 'C', 'D'] , name='Genus'))
df
# Out:
# Genus         A         B         C         D
# one    0.517975  0.649233  0.349540  0.047203
# two    0.254314  0.988426  0.125302  0.007515
# three  0.979797  0.278122  0.282529  0.627896
# four   0.033625  0.289613  0.716647  0.398485
# five   0.154822  0.833390  0.702895  0.221069
# six    0.910670  0.379145  0.627183  0.221949

# %%
df.plot.barh(figsize=(20,12))

# %%
df.plot.bar(figsize=(20,12),fontsize='large')
# plt.autoscale()
fig.autofmt_xdate(rotation=90) #自动旋转横坐标

# %%
df.plot.barh(figsize=(20,12),stacked=True, alpha=0.8) # 堆积柱状图

# %%
import seaborn as sns

# %%
df.A.plot.hist(bins=5)

# %%
df.B.plot.density()

# %%
sns.distplot(df.C, bins=10, color='k')

# %%
df=pd.DataFrame([np.arange(50),2*np.random.randn(50)],index=list('AB')).T
df.head(3)
# Out:
#      A         B
# 0  0.0  0.426913
# 1  1.0 -0.167332
# 2  2.0 -0.071906

# %%
trans_data = np.log(df).diff().dropna()
sns.regplot('A','B',data=trans_data)
plt.title('Changes in log %s versus log %s' % ('m1', ' unemp'))
# Out:
# /Users/mac/.pyenv/versions/3.7.3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# /Users/mac/.pyenv/versions/3.7.3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
# Text(0.5, 1.0, 'Changes in log m1 versus log  unemp')

# %%
sns.pairplot(trans_data, diag_kind='kde', plot_kws={'alpha': 0.2}) 
#在探索式数据分析工作中,同时观察一组变量的散布图是很有意义的,这也被称为散布图矩阵(scatter plot matrix)

# %% [markdown]
# # 第 10 章 数据聚合与分组运算

# %% [markdown]
# ## 10.1 数据分组

# %%
df = pd.DataFrame({'key1':['a','a','b','b','a'],
                 'key2':['one','two','one','two','one'],
                 'data1': np.random.randn(5),
                 'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.018577 -0.211392
# 1    a  two  0.084371  0.109923
# 2    b  one  0.095883 -0.341697
# 3    b  two  0.939246 -0.858792
# 4    a  one -0.127181  0.519882

# %%
grouped = df['data1'].groupby(df['key1'])

# %%
grouped.mean()
# Out:
# key1
# a   -0.008078
# b    0.517565
# Name: data1, dtype: float64

# %%
grouped = df['data1'].groupby([df['key1'],df['key2']])

# %%
grouped.mean()
# Out:
# key1  key2
# a     one    -0.054302
#       two     0.084371
# b     one     0.095883
#       two     0.939246
# Name: data1, dtype: float64

# %%
grouped.mean().unstack()
# Out:
# key2       one       two
# key1
# a    -0.054302  0.084371
# b     0.095883  0.939246

# %% [markdown]
# 分组键可以是任何长度适当的数组:

# %%
states = np.array(['Ohio', 'California', 'California', 'Ohio', 'Ohio'])

# %%
years = np.array([2005, 2005, 2006, 2005, 2006])

# %%
df['data1'].groupby([states, years]).mean()
# Out:
# California  2005    0.084371
#             2006    0.095883
# Ohio        2005    0.478911
#             2006   -0.127181
# Name: data1, dtype: float64

# %%
df.groupby(['key1', 'key2']).size()
# Out:
# key1  key2
# a     one     2
#       two     1
# b     one     1
#       two     1
# dtype: int64

# %% [markdown]
# 对分组进行迭代

# %%
for name, group in df.groupby('key1'):
    print(name)    
    print(group)
# Out:
# a
#   key1 key2     data1     data2
# 0    a  one  0.018577 -0.211392
# 1    a  two  0.084371  0.109923
# 4    a  one -0.127181  0.519882
# b
#   key1 key2     data1     data2
# 2    b  one  0.095883 -0.341697
# 3    b  two  0.939246 -0.858792

# %%
for (k1, k2), group in df.groupby(['key1', 'key2']): 
    print((k1, k2))
    print(group)
# Out:
# ('a', 'one')
#   key1 key2     data1     data2
# 0    a  one  0.018577 -0.211392
# 4    a  one -0.127181  0.519882
# ('a', 'two')
#   key1 key2     data1     data2
# 1    a  two  0.084371  0.109923
# ('b', 'one')
#   key1 key2     data1     data2
# 2    b  one  0.095883 -0.341697
# ('b', 'two')
#   key1 key2     data1     data2
# 3    b  two  0.939246 -0.858792

# %%
pieces = dict(list(df.groupby('key1'))) #数据片段做成一个字典
pieces['a']
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.018577 -0.211392
# 1    a  two  0.084371  0.109923
# 4    a  one -0.127181  0.519882

# %% [markdown]
# groupby默认是在axis=0上进行分组的,通过设置也可以在其他任何轴上进行分组。

# %%
df.dtypes
# Out:
# key1      object
# key2      object
# data1    float64
# data2    float64
# dtype: object

# %%
for dtype,group in df.groupby(df.dtypes,axis=1):
    print(dtype)
    print(group)
# Out:
# float64
#       data1     data2
# 0  0.018577 -0.211392
# 1  0.084371  0.109923
# 2  0.095883 -0.341697
# 3  0.939246 -0.858792
# 4 -0.127181  0.519882
# object
#   key1 key2
# 0    a  one
# 1    a  two
# 2    b  one
# 3    b  two
# 4    a  one

# %% [markdown]
# 对于大数据集,很可能只需要对部分列进行聚合

# %%
df.groupby(['key1', 'key2'])[['data2']].mean()
# Out:
#               data2
# key1 key2
# a    one   0.154245
#      two   0.109923
# b    one  -0.341697
#      two  -0.858792

# %% [markdown]
# 通过字典或Series进行分组

# %%
people = pd.DataFrame(np.random.randn(5, 5),
                      columns=['a', 'b', 'c', 'd', 'e'],
                      index=['Joe', 'Steve', 'Wes', 'Jim', 'Travis'])
people
# Out:
#                a         b         c         d         e
# Joe    -1.035268  0.596914  0.303241  0.797063 -0.680255
# Steve  -0.075716  1.856177  1.963454 -0.270171  0.237689
# Wes     1.143721 -0.324616  1.070960 -0.046627 -0.611714
# Jim     0.001762  0.944410  1.462368  0.037823  0.194062
# Travis  0.772439 -1.552445  0.511785  0.389323  1.191414

# %%
people.iloc[2:3,[1,2]] = np.nan

# %%
people
# Out:
#                a         b         c         d         e
# Joe    -1.035268  0.596914  0.303241  0.797063 -0.680255
# Steve  -0.075716  1.856177  1.963454 -0.270171  0.237689
# Wes     1.143721       NaN       NaN -0.046627 -0.611714
# Jim     0.001762  0.944410  1.462368  0.037823  0.194062
# Travis  0.772439 -1.552445  0.511785  0.389323  1.191414

# %%
mapping = {'a': 'red', 'b': 'red', 'c': 'blue','d': 'blue', 'e': 'red', 'f' : 'orange'}

# %%
by_column = people.groupby(mapping, axis=1)

# %%
by_column.count()
# Out:
#         blue  red
# Joe        2    3
# Steve      2    3
# Wes        1    2
# Jim        2    3
# Travis     2    3

# %%
map_series = pd.Series(mapping)

# %%
people.groupby(map_series, axis=1).count()
# Out:
#         blue  red
# Joe        2    3
# Steve      2    3
# Wes        1    2
# Jim        2    3
# Travis     2    3

# %% [markdown]
# 比起使用字典或Series,使用Python函数是一种更原生的方法定义分组映射。任何被当做分组键的函数都会在各个索引值上被调用一次,其返回值就会被用作分组名称。

# %%
people.groupby(len).sum()
# Out:
#           a         b         c         d         e
# 3  0.110214  1.541323  1.765608  0.788260 -1.097907
# 5 -0.075716  1.856177  1.963454 -0.270171  0.237689
# 6  0.772439 -1.552445  0.511785  0.389323  1.191414

# %% [markdown]
# 将函数跟数组、列表、字典、Series混合使用也不是问题,因为任何东西在内部都会被转换为数组

# %%
key_list = ['one', 'one', 'one', 'two', 'two']

# %%
people.groupby([len, key_list]).min()
# Out:
#               a         b         c         d         e
# 3 one -1.035268  0.596914  0.303241 -0.046627 -0.680255
#   two  0.001762  0.944410  1.462368  0.037823  0.194062
# 5 one -0.075716  1.856177  1.963454 -0.270171  0.237689
# 6 two  0.772439 -1.552445  0.511785  0.389323  1.191414

# %%
columns = pd.MultiIndex.from_arrays([['US', 'US', 'US', 'JP', 'JP'],  
                                     [1, 3, 5, 1, 3]],  
                                    names=['cty', 'tenor'])
columns
# Out:
# MultiIndex([('US', 1),
#             ('US', 3),
#             ('US', 5),
#             ('JP', 1),
#             ('JP', 3)],
#            names=['cty', 'tenor'])

# %%
hier_df = pd.DataFrame(np.random.randn(4, 5), columns=columns)
hier_df
# Out:
# cty          US                            JP
# tenor         1         3         5         1         3
# 0      1.306367  0.542717  0.380685 -0.196638 -1.448875
# 1      0.358827 -1.211705  1.727599 -1.503298 -0.150531
# 2      0.349679  0.711785 -1.448705 -1.063593  1.918026
# 3     -0.305030 -0.916053  0.883847 -1.051206  0.037105

# %%
hier_df.groupby(level='cty', axis=1).count()
# Out:
# cty  JP  US
# 0     2   3
# 1     2   3
# 2     2   3
# 3     2   3

# %% [markdown]
# ## 10.2 数据聚合

# %% [markdown]
# quantile可以计算Series或DataFrame列的样本分位数

# %%
df = pd.DataFrame({'key1':['a','a','b','b','a'],
                 'key2':['one','two','one','two','one'],
                 'data1': np.random.randn(5),
                 'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.674440  1.400580
# 1    a  two -0.303452 -0.376757
# 2    b  one  0.702463  1.602098
# 3    b  two -1.822169  0.705157
# 4    a  one -0.800331 -0.212590

# %%
grouped = df.groupby('key1')

# %%
grouped['data1'].quantile(0.9)
# Out:
# key1
# a   -0.37765
# b    0.45000
# Name: data1, dtype: float64

# %%
def peak_to_peak(arr):
    return arr.max() - arr.min()
    grouped.agg(peak_to_peak)

# %%
grouped.agg(peak_to_peak)
# Out:
#          data1     data2
# key1
# a     0.496879  1.777338
# b     2.524632  0.896941

# %%
grouped.describe()
# Out:
#      data1                                                              \
#      count      mean       std       min       25%       50%       75%
# key1
# a      3.0 -0.592741  0.258318 -0.800331 -0.737386 -0.674440 -0.488946
# b      2.0 -0.559853  1.785184 -1.822169 -1.191011 -0.559853  0.071305
#
#                data2                                                    \
#            max count      mean       std       min       25%       50%
# key1
# a    -0.303452   3.0  0.270411  0.982191 -0.376757 -0.294674 -0.212590
# b     0.702463   2.0  1.153628  0.634233  0.705157  0.929393  1.153628
#
#
#            75%       max
# key1
# a     0.593995  1.400580
# b     1.377863  1.602098

# %%
grouped.std()
# Out:
#          data1     data2
# key1
# a     0.258318  0.982191
# b     1.785184  0.634233

# %%
面向列的多函数应用

# %%
grouped.aggregate([np.std,np.var])
# Out:
#          data1               data2
#            std       var       std       var
# key1
# a     0.258318  0.066728  0.982191  0.964700
# b     1.785184  3.186883  0.634233  0.402252

# %%
tips = pd.read_clipboard()
tips
# Out:
#    total_bill   tip smoker   day    time  size   tip_pct
# 0       16.99  1.01     No   Mon  Dinner     2  0.059447
# 1       10.34  1.66     No   Sun  Dinner     3  0.160542
# 2       21.01  3.50    Yes   Thr  Dinner     3  0.166587
# 3       23.68  3.31     No   Sun  Dinner     2  0.139780
# 4       24.59  3.61    Yes  Wesn  Dinner     4  0.146808
# 5       25.29  4.71     No   Sun  Dinner     4  0.186240

# %%
grouped = tips.groupby(['day', 'smoker'])

# %%
grouped.tip_pct.agg(['mean', 'std', peak_to_peak])
# Out:
#                  mean       std  peak_to_peak
# day  smoker
# Mon  No      0.059447       NaN       0.00000
# Sun  No      0.162187  0.023274       0.04646
# Thr  Yes     0.166587       NaN       0.00000
# Wesn Yes     0.146808       NaN       0.00000

# %%
grouped.tip_pct.agg([('foo', 'mean'), ('bar', np.std)]) 
#如果传入的是一个由(name,function)元组组成的列表,
# 则各元组的第一个元素就会被用作DataFrame的列名
# Out:
#                   foo       bar
# day  smoker
# Mon  No      0.059447       NaN
# Sun  No      0.162187  0.023274
# Thr  Yes     0.166587       NaN
# Wesn Yes     0.146808       NaN

# %%
functions = ['count', 'mean', 'max']
grouped['tip_pct', 'total_bill'].agg(functions)
# Out:
# /Users/mac/.pyenv/versions/3.7.3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#             tip_pct                     total_bill
#               count      mean       max      count   mean    max
# day  smoker
# Mon  No           1  0.059447  0.059447          1  16.99  16.99
# Sun  No           3  0.162187  0.186240          3  19.77  25.29
# Thr  Yes          1  0.166587  0.166587          1  21.01  21.01
# Wesn Yes          1  0.146808  0.146808          1  24.59  24.59

# %%
ftuples = [('Durchschnitt', 'mean'),('Abweichung', np.var)]
grouped['tip_pct', 'total_bill'].agg(ftuples)
# Out:
# /Users/mac/.pyenv/versions/3.7.3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                  tip_pct              total_bill
#             Durchschnitt Abweichung Durchschnitt Abweichung
# day  smoker
# Mon  No         0.059447        NaN        16.99        NaN
# Sun  No         0.162187   0.000542        19.77    67.3417
# Thr  Yes        0.166587        NaN        21.01        NaN
# Wesn Yes        0.146808        NaN        24.59        NaN

# %%
grouped.agg({'tip' : np.max, 'size' : 'sum'}) #对一个列或不同的列应用不同的函数
# Out:
#               tip  size
# day  smoker
# Mon  No      1.01     2
# Sun  No      4.71     9
# Thr  Yes     3.50     3
# Wesn Yes     3.61     4

# %%
grouped.agg({'tip_pct' : ['min', 'max', 'mean', 'std'],'size' : 'sum'})
# Out:
#               tip_pct                               size
#                   min       max      mean       std  sum
# day  smoker
# Mon  No      0.059447  0.059447  0.059447       NaN    2
# Sun  No      0.139780  0.186240  0.162187  0.023274    9
# Thr  Yes     0.166587  0.166587  0.166587       NaN    3
# Wesn Yes     0.146808  0.146808  0.146808       NaN    4

# %% [markdown]
# 以“没有行索引”的形式返回聚合数据

# %%
tips.groupby(['day', 'smoker'], as_index=False).mean()
# Out:
#     day smoker  total_bill       tip  size   tip_pct
# 0   Mon     No       16.99  1.010000     2  0.059447
# 1   Sun     No       19.77  3.226667     3  0.162187
# 2   Thr    Yes       21.01  3.500000     3  0.166587
# 3  Wesn    Yes       24.59  3.610000     4  0.146808

# %% [markdown]
# apply:一般性的“拆分-应用-合并”

# %%
def top(df, n=5, column='tip_pct'):
    return df.sort_values(by=column)[-n:]

# %%
top(tips, n=6)
# Out:
#    total_bill   tip smoker   day    time  size   tip_pct
# 0       16.99  1.01     No   Mon  Dinner     2  0.059447
# 3       23.68  3.31     No   Sun  Dinner     2  0.139780
# 4       24.59  3.61    Yes  Wesn  Dinner     4  0.146808
# 1       10.34  1.66     No   Sun  Dinner     3  0.160542
# 2       21.01  3.50    Yes   Thr  Dinner     3  0.166587
# 5       25.29  4.71     No   Sun  Dinner     4  0.186240

# %%
tips.groupby('smoker').apply(top)
# Out:
#           total_bill   tip smoker   day    time  size   tip_pct
# smoker
# No     0       16.99  1.01     No   Mon  Dinner     2  0.059447
#        3       23.68  3.31     No   Sun  Dinner     2  0.139780
#        1       10.34  1.66     No   Sun  Dinner     3  0.160542
#        5       25.29  4.71     No   Sun  Dinner     4  0.186240
# Yes    4       24.59  3.61    Yes  Wesn  Dinner     4  0.146808
#        2       21.01  3.50    Yes   Thr  Dinner     3  0.166587

# %%
tips.groupby(['smoker', 'day']).apply(top, n=1, column= 'total_bill')
# Out:
#                total_bill   tip smoker   day    time  size   tip_pct
# smoker day
# No     Mon  0       16.99  1.01     No   Mon  Dinner     2  0.059447
#        Sun  5       25.29  4.71     No   Sun  Dinner     4  0.186240
# Yes    Thr  2       21.01  3.50    Yes   Thr  Dinner     3  0.166587
#        Wesn 4       24.59  3.61    Yes  Wesn  Dinner     4  0.146808

# %%
tips.groupby('smoker')['tip_pct'].describe()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# smoker
# No        4.0  0.136502  0.054772  0.059447  0.119697  0.150161  0.166967
# Yes       2.0  0.156697  0.013986  0.146808  0.151753  0.156697  0.161642
#
#              max
# smoker
# No      0.186240
# Yes     0.166587

# %%
Out[80].unstack()
# Out:
#        smoker
# count  No        4.000000
#        Yes       2.000000
# mean   No        0.136502
#        Yes       0.156697
# std    No        0.054772
#        Yes       0.013986
# min    No        0.059447
#        Yes       0.146808
# 25%    No        0.119697
#        Yes       0.151753
# 50%    No        0.150161
#        Yes       0.156697
# 75%    No        0.166967
#        Yes       0.161642
# max    No        0.186240
#        Yes       0.166587
# dtype: float64

# %% [markdown]
# 在GroupBy中,当你调用诸如describe之类的方法时,实际上只是应用了下面两条代码的快捷方式而已:

# %%
f = lambda x: x.describe() 
grouped.apply(f)
# Out:
#                    total_bill       tip  size   tip_pct
# day  smoker
# Mon  No     count    1.000000  1.000000   1.0  1.000000
#             mean    16.990000  1.010000   2.0  0.059447
#             std           NaN       NaN   NaN       NaN
#             min     16.990000  1.010000   2.0  0.059447
#             25%     16.990000  1.010000   2.0  0.059447
#             50%     16.990000  1.010000   2.0  0.059447
#             75%     16.990000  1.010000   2.0  0.059447
#             max     16.990000  1.010000   2.0  0.059447
# Sun  No     count    3.000000  3.000000   3.0  3.000000
#             mean    19.770000  3.226667   3.0  0.162187
#             std      8.206199  1.526707   1.0  0.023274
#             min     10.340000  1.660000   2.0  0.139780
#             25%     17.010000  2.485000   2.5  0.150161
#             50%     23.680000  3.310000   3.0  0.160542
#             75%     24.485000  4.010000   3.5  0.173391
#             max     25.290000  4.710000   4.0  0.186240
# ...

# %%
# 禁止分组键
tips.groupby('smoker', group_keys=False).apply(top)
# Out:
#    total_bill   tip smoker   day    time  size   tip_pct
# 0       16.99  1.01     No   Mon  Dinner     2  0.059447
# 3       23.68  3.31     No   Sun  Dinner     2  0.139780
# 1       10.34  1.66     No   Sun  Dinner     3  0.160542
# 5       25.29  4.71     No   Sun  Dinner     4  0.186240
# 4       24.59  3.61    Yes  Wesn  Dinner     4  0.146808
# 2       21.01  3.50    Yes   Thr  Dinner     3  0.166587

# %% [markdown]
# ## 10.3 分位数和桶分析

# %% [markdown]
# pandas有一些能根据指定面元或样本分位数将数据拆分成多块的工具(比如cut和qcut)。将这些函数跟groupby结合起来,就能非常轻松地实现对数据集的桶(bucket)或分位数(quantile)分析了。

# %%
frame = pd.DataFrame({'data1': np.random.randn(1000),
                      'data2': np.random.randn(1000)})
frame
# Out:
#         data1     data2
# 0   -1.333382  0.301203
# 1   -1.071817  0.029334
# 2    0.527277 -0.345090
# 3    0.326873 -0.067388
# 4    0.863973  0.817286
# ..        ...       ...
# 995 -0.973621 -1.323128
# 996  0.576833 -0.940627
# 997  0.954485 -0.563705
# 998  0.570575 -0.369755
# 999 -0.207589 -1.232257
#
# [1000 rows x 2 columns]

# %%
quartiles = pd.cut(frame.data1, 4) # 长度相等的桶
quartiles
# Out:
# 0      (-1.636, -0.209]
# 1      (-1.636, -0.209]
# 2       (-0.209, 1.217]
# 3       (-0.209, 1.217]
# 4       (-0.209, 1.217]
#              ...
# 995    (-1.636, -0.209]
# 996     (-0.209, 1.217]
# 997     (-0.209, 1.217]
# 998     (-0.209, 1.217]
# 999     (-0.209, 1.217]
# Name: data1, Length: 1000, dtype: category
# Categories (4, interval[float64]): [(-3.068, -1.636] < (-1.636, -0.209] < (-0.209, 1.217] < (1.217, 2.644]]

# %%
def get_stats(group):
        return {'min': group.min(), 'max': group.max(),
        'count': group.count(), 'mean': group.mean( )}

# %%
grouped = frame.data2.groupby(quartiles)

# %%
grouped.apply(get_stats).unstack()
# Out:
#                        min       max  count      mean
# data1
# (-3.068, -1.636] -3.299021  2.407302   53.0 -0.111033
# (-1.636, -0.209] -3.188232  3.267486  354.0 -0.039256
# (-0.209, 1.217]  -2.989736  2.893565  499.0 -0.010299
# (1.217, 2.644]   -3.287306  2.473870   94.0  0.129700

# %% [markdown]
# 要根据样本分位数得到大小相等的桶,使用qcut即可。传入labels=False即可只获取分位数的编号

# %%
grouping = pd.qcut(frame.data1, 10, labels=False)

# %%
grouped = frame.data2.groupby(grouping)

# %%
grouped.apply(get_stats).unstack()
# Out:
#             min       max  count      mean
# data1
# 0     -3.299021  2.407302  100.0 -0.070893
# 1     -2.382464  3.233644  100.0 -0.172752
# 2     -3.188232  3.267486  100.0  0.053058
# 3     -3.015771  2.513921  100.0 -0.042230
# 4     -1.912233  2.712412  100.0  0.162031
# 5     -2.208691  2.893565  100.0 -0.030433
# 6     -2.700064  2.316721  100.0  0.049922
# 7     -2.989736  2.117346  100.0 -0.080709
# 8     -1.730168  2.589908  100.0 -0.104620
# 9     -3.287306  2.473870  100.0  0.109338

# %% [markdown]
# ### 示例:用特定于分组的值填充缺失值

# %%
s = pd.Series(np.random.randn(6))
s[::2] = np.nan
s
# Out:
# 0         NaN
# 1   -0.735501
# 2         NaN
# 3    0.877388
# 4         NaN
# 5    0.759008
# dtype: float64

# %%
s.fillna(s.mean())
# Out:
# 0    0.300298
# 1   -0.735501
# 2    0.300298
# 3    0.877388
# 4    0.300298
# 5    0.759008
# dtype: float64

# %%
states = ['Ohio', 'New York', 'Vermont', 'Florida',
          'Oregon', 'Nevada', 'California', 'Idaho']
group_key = ['East'] * 4 + ['West'] * 4
data = pd.Series(np.random.randn(8), index=states)
data
# Out:
# Ohio          0.414257
# New York     -0.695368
# Vermont       0.062875
# Florida       1.732473
# Oregon       -1.102514
# Nevada       -0.749348
# California   -0.108139
# Idaho         2.373886
# dtype: float64

# %%
data[['Vermont', 'Nevada', 'Idaho']] = np.nan

# %%
data
# Out:
# Ohio          0.414257
# New York     -0.695368
# Vermont            NaN
# Florida       1.732473
# Oregon       -1.102514
# Nevada             NaN
# California   -0.108139
# Idaho              NaN
# dtype: float64

# %%
data.groupby(group_key).mean()
# Out:
# East    0.483787
# West   -0.605326
# dtype: float64

# %% [markdown]
# 用分组平均值去填充NA值:

# %%
fill_mean = lambda g: g.fillna(g.mean())
data.groupby(group_key).apply(fill_mean)
# Out:
# Ohio          0.414257
# New York     -0.695368
# Vermont       0.483787
# Florida       1.732473
# Oregon       -1.102514
# Nevada       -0.605326
# California   -0.108139
# Idaho        -0.605326
# dtype: float64

# %%
fill_values = {'East': 0.5, 'West': -1}

# %%
fill_func = lambda g: g.fillna(fill_values[g.name])
data.groupby(group_key).apply(fill_func)
# Out:
# Ohio          0.414257
# New York     -0.695368
# Vermont       0.500000
# Florida       1.732473
# Oregon       -1.102514
# Nevada       -1.000000
# California   -0.108139
# Idaho        -1.000000
# dtype: float64

# %% [markdown]
# ### 示例:随机采样和排列

# %%
# Hearts, Spades, Clubs, Diamonds 
suits = ['H', 'S', 'C', 'D'] 
card_val = (list(range(1, 11)) + [10] * 3) * 4 
base_names = ['A'] + list(range(2, 11)) + ['J', 'K', 'Q'] 
cards = [] 
for suit in ['H', 'S', 'C', 'D']:     
    cards.extend(str(num) + suit for num in base_names) 
deck = pd.Series(card_val, index=cards)

# %%
deck[:13]
# Out:
# AH      1
# 2H      2
# 3H      3
# 4H      4
# 5H      5
# 6H      6
# 7H      7
# 8H      8
# 9H      9
# 10H    10
# JH     10
# KH     10
# QH     10
# dtype: int64

# %%
def draw(deck, n=5):
    return deck.sample(n)

# %%
draw(deck)
# Out:
# 3D      3
# 6H      6
# 10C    10
# AC      1
# 7D      7
# dtype: int64

# %%
get_suit = lambda card: card[-1] # last letter is suit
deck.groupby(get_suit).apply(draw, n=2)
# Out:
# C  5C     5
#    3C     3
# D  6D     6
#    AD     1
# H  8H     8
#    KH    10
# S  4S     4
#    7S     7
# dtype: int64

# %%
deck.groupby(get_suit, group_keys=False).apply(draw, n= 2)
# Out:
# 8C     8
# 3C     3
# 7D     7
# 4D     4
# JH    10
# 8H     8
# QS    10
# KS    10
# dtype: int64

# %% [markdown]
# ### 示例:分组加权平均数和相关系数

# %%
df = pd.DataFrame({'category': ['a', 'a', 'a', 'a','b', 'b', 'b', 'b'],
                   'data': np.random.randn(8), 
                   'weights': np.random.rand(8)})
df
# Out:
#   category      data   weights
# 0        a  1.641692  0.052102
# 1        a -0.396673  0.966709
# 2        a  0.017717  0.175927
# 3        a  2.259736  0.361060
# 4        b -0.549144  0.549370
# 5        b  1.351150  0.194726
# 6        b -0.165149  0.820149
# 7        b -0.124360  0.183434

# %%
grouped = df.groupby('category')

# %%
get_wavg = lambda g: np.average(g['data'], weights=g['weights'])

# %%
grouped.apply(get_wavg)
# Out:
# category
# a    0.334932
# b   -0.112628
# dtype: float64

# %%
cpx = pd.read_csv('stock_px.csv', parse_dates=True,index_col=0)
cpx
# Out:
#               AAPL   MSFT    XOM      SPX
# 2003-01-02    7.40  21.11  29.22   909.03
# 2003-01-03    7.45  21.14  29.24   908.59
# 2003-01-06    7.45  21.52  29.96   929.01
# 2003-01-07    7.43  21.93  28.95   922.93
# 2003-01-08    7.28  21.31  28.83   909.93
# ...            ...    ...    ...      ...
# 2011-10-10  388.81  26.94  76.28  1194.89
# 2011-10-11  400.29  27.00  76.27  1195.54
# 2011-10-12  402.19  26.96  77.16  1207.25
# 2011-10-13  408.43  27.18  76.37  1203.66
# 2011-10-14  422.00  27.27  78.11  1224.58
#
# [2214 rows x 4 columns]

# %%
spx_corr = lambda x: x.corrwith(x['SPX'])

# %%
rets = cpx.pct_change().dropna()
rets
# Out:
#                 AAPL      MSFT       XOM       SPX
# 2003-01-03  0.006757  0.001421  0.000684 -0.000484
# 2003-01-06  0.000000  0.017975  0.024624  0.022474
# 2003-01-07 -0.002685  0.019052 -0.033712 -0.006545
# 2003-01-08 -0.020188 -0.028272 -0.004145 -0.014086
# 2003-01-09  0.008242  0.029094  0.021159  0.019386
# ...              ...       ...       ...       ...
# 2011-10-10  0.051406  0.026286  0.036977  0.034125
# 2011-10-11  0.029526  0.002227 -0.000131  0.000544
# 2011-10-12  0.004747 -0.001481  0.011669  0.009795
# 2011-10-13  0.015515  0.008160 -0.010238 -0.002974
# 2011-10-14  0.033225  0.003311  0.022784  0.017380
#
# [2213 rows x 4 columns]

# %%
get_year = lambda x: x.year

# %%
by_year = rets.groupby(get_year) 
by_year.apply(spx_corr)
# Out:
#           AAPL      MSFT       XOM  SPX
# 2003  0.541124  0.745174  0.661265  1.0
# 2004  0.374283  0.588531  0.557742  1.0
# 2005  0.467540  0.562374  0.631010  1.0
# 2006  0.428267  0.406126  0.518514  1.0
# 2007  0.508118  0.658770  0.786264  1.0
# 2008  0.681434  0.804626  0.828303  1.0
# 2009  0.707103  0.654902  0.797921  1.0
# 2010  0.710105  0.730118  0.839057  1.0
# 2011  0.691931  0.800996  0.859975  1.0

# %%
by_year.apply(lambda g: g['AAPL'].corr(g['MSFT']))
# Out:
# 2003    0.480868
# 2004    0.259024
# 2005    0.300093
# 2006    0.161735
# 2007    0.417738
# 2008    0.611901
# 2009    0.432738
# 2010    0.571946
# 2011    0.581987
# dtype: float64

# %% [markdown]
# ### 示例:组级别的线性回归

# %%
import statsmodels.api as sm 
def regress(data, yvar, xvars):     
    Y = data[yvar]     
    X = data[xvars]     
    X['intercept'] = 1.
    result = sm.OLS(Y, X).fit()     
    return result.params

# %%
by_year.apply(regress, 'AAPL', ['SPX'])
# Out:
#            SPX  intercept
# 2003  1.195406   0.000710
# 2004  1.363463   0.004201
# 2005  1.766415   0.003246
# 2006  1.645496   0.000080
# 2007  1.198761   0.003438
# 2008  0.968016  -0.001110
# 2009  0.879103   0.002954
# 2010  1.052608   0.001261
# 2011  0.806605   0.001514

# %% [markdown]
# ## 10.4 透视表和交叉表

# %%
tips.pivot_table(index=['day', 'smoker'])
# Out:
#              size       tip   tip_pct  total_bill
# day  smoker
# Mon  No         2  1.010000  0.059447       16.99
# Sun  No         3  3.226667  0.162187       19.77
# Thr  Yes        3  3.500000  0.166587       21.01
# Wesn Yes        4  3.610000  0.146808       24.59

# %%
tips.pivot_table(['tip_pct', 'size'], index=['time', 'day'],columns='smoker',margins=True,fill_value=0
                )
# Out:
#              size            tip_pct
# smoker         No  Yes All        No       Yes       All
# time   day
# Dinner Mon   2.00  0.0   2  0.059447  0.000000  0.059447
#        Sun   3.00  0.0   3  0.162187  0.000000  0.162187
#        Thr   0.00  3.0   3  0.000000  0.166587  0.166587
#        Wesn  0.00  4.0   4  0.000000  0.146808  0.146808
# All          2.75  3.5   3  0.136502  0.156697  0.143234

# %%
tips.pivot_table('tip_pct', index=['time', 'smoker'], columns='day',aggfunc=len, margins=True,fill_value=0)
# Out:
# day            Mon  Sun  Thr  Wesn  All
# time   smoker
# Dinner No        1    3    0     0  4.0
#        Yes       0    0    1     1  2.0
# All              1    3    1     1  6.0

# %%
data = pd.read_clipboard()
data
# Out:
#   Nationality    Handedness
# 0         USA  Right-handed
# 1       Japan   Left-handed
# 2         USA  Right-handed
# 3       Japan  Right-handed
# 4       Japan   Left-handed
# 5       Japan  Right-handed
# 6         USA  Right-handed
# 7         USA   Left-handed
# 8       Japan  Right-handed
# 9         USA  Right-handed

# %%
pd.crosstab(data.Nationality, data.Handedness, margins= True)
# Out:
# Handedness   Left-handed  Right-handed  All
# Nationality
# Japan                  2             3    5
# USA                    1             4    5
# All                    3             7   10

# %%
pd.crosstab([tips.time, tips.day], tips.smoker, margins=True)
# Out:
# smoker       No  Yes  All
# time   day
# Dinner Mon    1    0    1
#        Sun    3    0    3
#        Thr    0    1    1
#        Wesn   0    1    1
# All           4    2    6

# %% [markdown]
# # 第 11 章 时间序列

# %% [markdown]
# ## 返回当前时刻的日期和时

# %%
from datetime import datetime

datetime.now()
# Out:
# datetime.datetime(2020, 3, 7, 21, 42, 28, 55462)

# %%
datetime.now().month, datetime.now().day

datetime.now().year
# Out:
# 2020

# %% [markdown]
# ## 返回当前时刻的周数

# %%
datetime.now().weekday() + 1  #当前时刻是一周中的周几

datetime.now().isocalendar()  #当前时刻所在的周在全年的周里面是第几周
# Out:
# (2020, 10, 6)

# %% [markdown]
# ## 指定时间格式

# %%
datetime.now().date()
# Out:
# datetime.date(2020, 3, 7)

# %%
datetime.now().time()
# Out:
# datetime.time(21, 45, 12, 962043)

# %%
datetime.now().time().hour
# Out:
# 21

# %%
datetime.now().time().minute
# Out:
# 45

# %%
datetime.now().time().second
# Out:
# 25

# %%
a = datetime.now()
a

a.strftime("%Y-%M-%D")

a.strftime("%Y-%M-%D %H: %M: %S")
# Out:
# '2020-45-03/07/20 21: 45: 57'

# %% [markdown]
# ### 时间转为字符串

# %%
str(a)
# Out:
# '2020-03-07 21:45:57.928047'

# %% [markdown]
# ### 字符串转为时间

# %%
from dateutil.parser import parse

str_time = '2020/2/23'

b = parse(str_time)
b
# Out:
# datetime.datetime(2020, 2, 23, 0, 0)

# %%
type(b)
# Out:
# datetime.datetime

# %% [markdown]
# ## 时间索引

# %% [markdown]
# 时间索引就是根据时间来对时间格式的字段进行数据选取的一种索引方式。

# %%
Index = pd.DatetimeIndex([
    '2020-2-23', '2020-2-24', '2020-2-25', '2020-2-26', '2020-2-27',
    '2020-2-28', '2020-3-1'
])

df = pd.DataFrame(np.random.randint(1, 9, 7), index=Index)
df
# Out:
#             0
# 2020-02-23  7
# 2020-02-24  6
# 2020-02-25  7
# 2020-02-26  1
# 2020-02-27  2
# 2020-02-28  8
# 2020-03-01  7

# %%
df['2020-3']
# Out:
#             0
# 2020-03-01  7

# %%
df['2020-02-24':'2020-3-1']
# Out:
#             0
# 2020-02-24  6
# 2020-02-25  7
# 2020-02-26  1
# 2020-02-27  2
# 2020-02-28  8
# 2020-03-01  7

# %%
df = pd.read_clipboard()

df
# Out:
#   客户姓名  唯一识别码  年龄        成交时间
# 0   张通    101  31  2018-08-08
# 1   李谷    102  45  2018-08-09
# 2   孙凤    103  23  2018-08-10
# 3   赵恒    104  36  2018-08-11
# 4   王娜    105  21  2018-08-11

# %%
df.dtypes
# Out:
# 客户姓名     object
# 唯一识别码     int64
# 年龄        int64
# 成交时间     object
# dtype: object

# %%
df.成交时间 = df.成交时间.apply(pd.to_datetime)

# %%
df.dtypes
# Out:
# 客户姓名             object
# 唯一识别码             int64
# 年龄                int64
# 成交时间     datetime64[ns]
# dtype: object

# %%
df[df.成交时间 == datetime(2018, 8, 8)]
# Out:
#   客户姓名  唯一识别码  年龄       成交时间
# 0   张通    101  31 2018-08-08

# %%
df[df.成交时间 > datetime(2018, 8, 8)]
# Out:
#   客户姓名  唯一识别码  年龄       成交时间
# 1   李谷    102  45 2018-08-09
# 2   孙凤    103  23 2018-08-10
# 3   赵恒    104  36 2018-08-11
# 4   王娜    105  21 2018-08-11

# %%
df[(df.成交时间 >= datetime(2018, 8, 8)) & (df.成交时间 <= datetime(2018, 8, 10))]
# Out:
#   客户姓名  唯一识别码  年龄       成交时间
# 0   张通    101  31 2018-08-08
# 1   李谷    102  45 2018-08-09
# 2   孙凤    103  23 2018-08-10

# %% [markdown]
# ## 时间运算

# %%
delt_time = datetime(2020, 2, 23, 18, 45, 34) - datetime(2020, 1, 23, 20, 5, 3)
delt_time
# Out:
# datetime.timedelta(days=30, seconds=81631)

# %%
delt_time.days
# Out:
# 30

# %%
delt_time.seconds
# Out:
# 81631

# %%
print('相差%u小时' % (delt_time.seconds / 3600))
# Out:
# 相差22小时

# %%
delt_time.seconds / 3600
# Out:
# 22.67527777777778

# %% [markdown]
# ### 日期的范围、频率以及移动

# %%
dates = [datetime(2011, 1, 2), datetime(2011, 1, 5),
        datetime(2011, 1, 7), datetime(2011, 1, 8),
        datetime(2011, 1, 10), datetime(2011, 1, 12)] 
ts = pd.Series(np.random.randn(6), index=dates)
ts
# Out:
# 2011-01-02    0.684342
# 2011-01-05   -1.613736
# 2011-01-07    1.120315
# 2011-01-08   -0.413553
# 2011-01-10    0.830220
# 2011-01-12    0.284058
# dtype: float64

# %%
ts.resample('D')

# %%
ts
# Out:
# 2011-01-02    0.684342
# 2011-01-05   -1.613736
# 2011-01-07    1.120315
# 2011-01-08   -0.413553
# 2011-01-10    0.830220
# 2011-01-12    0.284058
# dtype: float64

# %%
pd.date_range('2020-01-01', '2020-12-01', freq='B') #工作日组成的日期索引
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-06',
#                '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10',
#                '2020-01-13', '2020-01-14',
#                ...
#                '2020-11-18', '2020-11-19', '2020-11-20', '2020-11-23',
#                '2020-11-24', '2020-11-25', '2020-11-26', '2020-11-27',
#                '2020-11-30', '2020-12-01'],
#               dtype='datetime64[ns]', length=240, freq='B')

# %%
pd.date_range('2012-05-02 12:56:31', periods=5, normalize=True)
# Out:
# DatetimeIndex(['2012-05-02', '2012-05-03', '2012-05-04', '2012-05-05',
#                '2012-05-06'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# ### timedelta 方法

# %%
from datetime import timedelta
datetime(2020, 2, 23, 18, 45, 34) + timedelta(days=1)

datetime(2020, 2, 23, 18, 45, 34) + timedelta(hours=1)
# Out:
# datetime.datetime(2020, 2, 23, 19, 45, 34)

# %% [markdown]
# ### offset 方法

# %%
from pandas.tseries.offsets import Day, Hour, Minute

datetime(2020, 2, 23, 18, 45, 34) + Day(2)

datetime(2020, 2, 23, 18, 45, 34) + Minute(3)
# Out:
# Timestamp('2020-02-23 18:48:34')

# %%
pd.date_range('2012-01-01', '2012-09-01', freq='WOM-3FRI') #月第3个星期五
# Out:
# DatetimeIndex(['2012-01-20', '2012-02-17', '2012-03-16', '2012-04-20',
#                '2012-05-18', '2012-06-15', '2012-07-20', '2012-08-17'],
#               dtype='datetime64[ns]', freq='WOM-3FRI')

# %% [markdown]
# ### 移动(超前和滞后)数据

# %%
ts = pd.Series(np.random.randn(4), index=pd.date_range('1/1/2000', periods=4 , freq='M'))
ts
# Out:
# 2000-01-31   -0.295246
# 2000-02-29    0.045596
# 2000-03-31   -0.147119
# 2000-04-30   -1.043609
# Freq: M, dtype: float64

# %%
ts.shift(2) #移动(shifting)指的是沿着时间轴将数据前移或后移。
# Out:
# 2000-01-31         NaN
# 2000-02-29         NaN
# 2000-03-31   -0.295246
# 2000-04-30    0.045596
# Freq: M, dtype: float64

# %%
ts.shift(-2)
# Out:
# 2000-01-31   -0.147119
# 2000-02-29   -1.043609
# 2000-03-31         NaN
# 2000-04-30         NaN
# Freq: M, dtype: float64

# %%
ts / ts.shift(1) - 1
# Out:
# 2000-01-31         NaN
# 2000-02-29   -1.154433
# 2000-03-31   -4.226576
# 2000-04-30    6.093656
# Freq: M, dtype: float64

# %%
ts.pct_change()
# Out:
# 2000-01-31         NaN
# 2000-02-29   -1.154433
# 2000-03-31   -4.226576
# 2000-04-30    6.093656
# Freq: M, dtype: float64

# %%
ts.shift(2, freq='M') #如果频率已知,则可以将其传给shift以便实现对时间戳进行位移而不是对数据进行简单位移
# Out:
# 2000-03-31   -0.295246
# 2000-04-30    0.045596
# 2000-05-31   -0.147119
# 2000-06-30   -1.043609
# Freq: M, dtype: float64

# %%
ts.shift(1, freq='90T')
# Out:
# 2000-01-31 01:30:00   -0.295246
# 2000-02-29 01:30:00    0.045596
# 2000-03-31 01:30:00   -0.147119
# 2000-04-30 01:30:00   -1.043609
# Freq: M, dtype: float64

# %% [markdown]
# ### 通过锚点偏移量的rollforward和rollback方法,可明确地将日期向前或向后“滚动

# %%
ts = pd.Series(np.random.randn(20),
               index=pd.date_range('1/15/2000', periods=20, freq='4d'))
ts
# Out:
# 2000-01-15    0.183460
# 2000-01-19    0.617722
# 2000-01-23    1.197539
# 2000-01-27   -0.754727
# 2000-01-31    1.019918
# 2000-02-04   -0.384300
# 2000-02-08    1.075766
# 2000-02-12   -1.091753
# 2000-02-16    1.049262
# 2000-02-20    1.583759
# 2000-02-24   -1.365043
# 2000-02-28   -0.293942
# 2000-03-03    0.547364
# 2000-03-07    0.087366
# 2000-03-11    0.499696
# 2000-03-15    0.166201
# 2000-03-19   -0.655048
# 2000-03-23   -0.529834
# 2000-03-27    0.195215
# 2000-03-31    0.348011
# Freq: 4D, dtype: float64

# %%
from pandas.tseries.offsets import Day, MonthEnd

# %%
offset = MonthEnd()
ts.groupby(offset.rollforward).mean()
# Out:
# 2000-01-31    0.452782
# 2000-02-29    0.081964
# 2000-03-31    0.082371
# dtype: float64

# %%
day_cut=['2000-01-15','2000-01-31','2000-02-28','2000-03-31']
day_cut = [parse(i) for i in day_cut]
cut = pd.cut(ts.index,day_cut)

# %%
day_cut
# Out:
# [datetime.datetime(2000, 1, 15, 0, 0),
#  datetime.datetime(2000, 1, 31, 0, 0),
#  datetime.datetime(2000, 2, 28, 0, 0),
#  datetime.datetime(2000, 3, 31, 0, 0)]

# %%
for i,j in ts.groupby(cut):
    print(i)
    print(j)
# Out:
# (2000-01-15, 2000-01-31]
# 2000-01-19    0.617722
# 2000-01-23    1.197539
# 2000-01-27   -0.754727
# 2000-01-31    1.019918
# Freq: 4D, dtype: float64
# (2000-01-31, 2000-02-28]
# 2000-02-04   -0.384300
# 2000-02-08    1.075766
# 2000-02-12   -1.091753
# 2000-02-16    1.049262
# 2000-02-20    1.583759
# 2000-02-24   -1.365043
# 2000-02-28   -0.293942
# Freq: 4D, dtype: float64
# (2000-02-28, 2000-03-31]
# 2000-03-03    0.547364
# 2000-03-07    0.087366
# 2000-03-11    0.499696
# 2000-03-15    0.166201
# 2000-03-19   -0.655048
# 2000-03-23   -0.529834
# 2000-03-27    0.195215
# 2000-03-31    0.348011
# Freq: 4D, dtype: float64

# %%
ts.groupby(cut).mean()
# Out:
# (2000-01-15, 2000-01-31]    0.520113
# (2000-01-31, 2000-02-28]    0.081964
# (2000-02-28, 2000-03-31]    0.082371
# dtype: float64

# %% [markdown]
# ## 11.5 时期及其算术运算

# %% [markdown]
# 时期(period)表示的是时间区间,比如数日、数月、数季、数年等。Period类所表示的就是这种数据类型,其构造函数需要用到一个字符串或整数

# %%
p = pd.Period(2007, freq='A-DEC') #Period对象表示的是从2007年1月1日到2007年12月31日之间的整段时间
p
# Out:
# Period('2007', 'A-DEC')

# %%
p+2
# Out:
# Period('2009', 'A-DEC')

# %%
p-2
# Out:
# Period('2005', 'A-DEC')

# %%
pd.Period('2014', freq='A-DEC') - p
# Out:
# <7 * YearEnds: month=12>

# %%
pd.period_range('2000-01-01', '2020-06-30', freq ='y') #period_range函数可用于创建规则的时期范围
# Out:
# PeriodIndex(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#              '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#              '2016', '2017', '2018', '2019', '2020'],
#             dtype='period[A-DEC]', freq='A-DEC')

# %%
values = ['2001Q3', '2002Q2', '2003Q1']
index = pd.PeriodIndex(values, freq='Q-DEC')
index
# Out:
# PeriodIndex(['2001Q3', '2002Q2', '2003Q1'], dtype='period[Q-DEC]', freq='Q-DEC')

# %% [markdown]
# ### 时期的频率转换

# %%
p.asfreq('M', how='start')
# Out:
# Period('2007-01', 'M')

# %%
p.asfreq('M', how='end')
# Out:
# Period('2007-12', 'M')

# %% [markdown]
# 在将高频率转换为低频率时,超时期(superperiod)是由子时期(subperiod)所属的位置决定的。

# %%
p = pd.Period('2007', freq='A-JUN')
p
# Out:
# Period('2007', 'A-JUN')

# %%
p.asfreq('M', 'start')
# Out:
# Period('2006-07', 'M')

# %%
p.asfreq('M', 'end')
# Out:
# Period('2007-06', 'M')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
rng = pd.period_range('2006', '2009', freq='A-DEC')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2006    0.854916
# 2007    0.038724
# 2008   -0.240306
# 2009   -0.010178
# Freq: A-DEC, dtype: float64

# %%
ts.asfreq('M', how='start')
# Out:
# 2006-01    0.854916
# 2007-01    0.038724
# 2008-01   -0.240306
# 2009-01   -0.010178
# Freq: M, dtype: float64

# %%
ts.asfreq('B', how='end')
# Out:
# 2006-12-29    0.854916
# 2007-12-31    0.038724
# 2008-12-31   -0.240306
# 2009-12-31   -0.010178
# Freq: B, dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
p = pd.Period('2012Q4', freq='Q-JAN') #以1月结束的财年,2012Q4是从11月到1月
p
# Out:
# Period('2012Q4', 'Q-JAN')

# %%
p.asfreq('D', 'start')
# Out:
# Period('2011-11-01', 'D')

# %%
p.asfreq('D', 'end')
# Out:
# Period('2012-01-31', 'D')

# %%
rng = pd.period_range('2011Q3', '2012Q4', freq='Q-JAN')

# %%
ts = pd.Series(np.arange(len(rng)), index=rng)

# %%
ts
# Out:
# 2011Q3    0
# 2011Q4    1
# 2012Q1    2
# 2012Q2    3
# 2012Q3    4
# 2012Q4    5
# Freq: Q-JAN, dtype: int64

# %%
new_rng = (rng.asfreq('B', 'e') - 1).asfreq('T', 's') + 16 * 60

# %%
ts.index = new_rng.to_timestamp()

# %%
ts
# Out:
# 2010-10-28 16:00:00    0
# 2011-01-28 16:00:00    1
# 2011-04-28 16:00:00    2
# 2011-07-28 16:00:00    3
# 2011-10-28 16:00:00    4
# 2012-01-30 16:00:00    5
# dtype: int64

# %% [markdown]
# ### 将Timestamp转换为Period(及其反向过程)

# %%
rng = pd.date_range('2000-01-01', periods=3, freq='M')

# %%
ts = pd.Series(np.random.randn(3), index=rng)
ts
# Out:
# 2000-01-31    0.283257
# 2000-02-29    1.308810
# 2000-03-31    1.125426
# Freq: M, dtype: float64

# %%
pts = ts.to_period()
pts
# Out:
# 2000-01    0.283257
# 2000-02    1.308810
# 2000-03    1.125426
# Freq: M, dtype: float64

# %%
rng = pd.date_range('1/29/2000', periods=6, freq='D')

# %%
ts2 = pd.Series(np.random.randn(6), index=rng)
ts2
# Out:
# 2000-01-29   -1.982144
# 2000-01-30    1.961638
# 2000-01-31    0.684947
# 2000-02-01    1.198289
# 2000-02-02    1.490960
# 2000-02-03    0.943136
# Freq: D, dtype: float64

# %%
ts2.to_period('M')
# Out:
# 2000-01   -1.982144
# 2000-01    1.961638
# 2000-01    0.684947
# 2000-02    1.198289
# 2000-02    1.490960
# 2000-02    0.943136
# Freq: M, dtype: float64

# %%
pts = ts2.to_period() #要转换回时间戳,使用to_timestamp即可
pts
# Out:
# 2000-01-29   -1.982144
# 2000-01-30    1.961638
# 2000-01-31    0.684947
# 2000-02-01    1.198289
# 2000-02-02    1.490960
# 2000-02-03    0.943136
# Freq: D, dtype: float64

# %%
pts.to_timestamp(how='end')
# Out:
# 2000-01-29 23:59:59.999999999   -1.982144
# 2000-01-30 23:59:59.999999999    1.961638
# 2000-01-31 23:59:59.999999999    0.684947
# 2000-02-01 23:59:59.999999999    1.198289
# 2000-02-02 23:59:59.999999999    1.490960
# 2000-02-03 23:59:59.999999999    0.943136
# Freq: D, dtype: float64

# %%
index = pd.PeriodIndex(year=data.year, quarter=data.quarter,freq='Q-DEC')
index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-8e9c89ed52c9> in <module>
# ----> 1 index = pd.PeriodIndex(year=data.year, quarter=data.quarter,freq='Q-DEC')
#       2 index
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## 11.6 重采样及频率转换

# %% [markdown]
# 重采样(resampling)指的是将时间序列从一个频率转换到另一个频率的处理过程。将高频率数据聚合到低频率称为降采样(downsampling),而将低频率数据转换到高频率则称为升采样(upsampling)。

# %%
rng = pd.date_range('2000-01-01', periods=100, freq='D' )
rng
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10', '2000-01-11', '2000-01-12',
#                '2000-01-13', '2000-01-14', '2000-01-15', '2000-01-16',
#                '2000-01-17', '2000-01-18', '2000-01-19', '2000-01-20',
#                '2000-01-21', '2000-01-22', '2000-01-23', '2000-01-24',
#                '2000-01-25', '2000-01-26', '2000-01-27', '2000-01-28',
#                '2000-01-29', '2000-01-30', '2000-01-31', '2000-02-01',
#                '2000-02-02', '2000-02-03', '2000-02-04', '2000-02-05',
#                '2000-02-06', '2000-02-07', '2000-02-08', '2000-02-09',
#                '2000-02-10', '2000-02-11', '2000-02-12', '2000-02-13',
#                '2000-02-14', '2000-02-15', '2000-02-16', '2000-02-17',
#                '2000-02-18', '2000-02-19', '2000-02-20', '2000-02-21',
# ...

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2000-01-01    0.331696
# 2000-01-02   -0.881754
# 2000-01-03    0.800261
# 2000-01-04    0.333241
# 2000-01-05    0.163545
#                 ...
# 2000-04-05   -0.119068
# 2000-04-06   -0.173527
# 2000-04-07    2.356129
# 2000-04-08    0.024536
# 2000-04-09   -1.725404
# Freq: D, Length: 100, dtype: float64

# %%
ts.resample('M').mean()
# Out:
# 2000-01-31   -0.219170
# 2000-02-29   -0.035667
# 2000-03-31   -0.050937
# 2000-04-30    0.208381
# Freq: M, dtype: float64

# %%
ts.resample('M', kind='period').mean()
# Out:
# 2000-01   -0.219170
# 2000-02   -0.035667
# 2000-03   -0.050937
# 2000-04    0.208381
# Freq: M, dtype: float64

# %%
rng = pd.date_range('2000-01-01', periods=12, freq='T' ) 
ts = pd.Series(np.arange(12), index=rng)
ts
# Out:
# 2000-01-01 00:00:00     0
# 2000-01-01 00:01:00     1
# 2000-01-01 00:02:00     2
# 2000-01-01 00:03:00     3
# 2000-01-01 00:04:00     4
# 2000-01-01 00:05:00     5
# 2000-01-01 00:06:00     6
# 2000-01-01 00:07:00     7
# 2000-01-01 00:08:00     8
# 2000-01-01 00:09:00     9
# 2000-01-01 00:10:00    10
# 2000-01-01 00:11:00    11
# Freq: T, dtype: int64

# %%
ts.resample('5min', closed='right').sum() #面元的右边界是包含的,因此00:00到00:05的区间中是包含00:05的
# Out:
# 1999-12-31 23:55:00     0
# 2000-01-01 00:00:00    15
# 2000-01-01 00:05:00    40
# 2000-01-01 00:10:00    11
# Freq: 5T, dtype: int64

# %%
ts.resample('5min', closed='right', label='right').sum ()
# Out:
# 2000-01-01 00:00:00     0
# 2000-01-01 00:05:00    15
# 2000-01-01 00:10:00    40
# 2000-01-01 00:15:00    11
# Freq: 5T, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ts.resample('5min', closed='right',label='right', loffset='-1s').sum()
# Out:
# 1999-12-31 23:59:59     0
# 2000-01-01 00:04:59    15
# 2000-01-01 00:09:59    40
# 2000-01-01 00:14:59    11
# Freq: 5T, dtype: int64

# %% [markdown]
# ### OHLC重采样

# %% [markdown]
# 金融领域中有一种无所不在的时间序列聚合方式,即计算各面元的四个值:第一个值(open,开盘)、最后一个值(close,收盘)、最大值(high,最高)以及最小值(low,最低)。传入how='ohlc'即可得到一个含有这四种聚合值的第 11 章 时间序列399 DataFrame。

# %%
ts.resample('5min').ohlc()
# Out:
#                      open  high  low  close
# 2000-01-01 00:00:00     0     4    0      4
# 2000-01-01 00:05:00     5     9    5      9
# 2000-01-01 00:10:00    10    11   10     11

# %% [markdown]
# ### 升采样和插值

# %%
frame = pd.DataFrame(np.random.randn(2, 4),
                     index=pd.date_range('1/1/2000',periods=2,freq='W-WED'),
                     columns=['Colorado', 'Texas', 'Ne w York', 'Ohio'])
frame
# Out:
#             Colorado     Texas  Ne w York      Ohio
# 2000-01-05  1.758510  0.374356   0.453846  1.746002
# 2000-01-12  0.686212  0.229502  -0.146142  1.221014

# %%
df_daily = frame.resample('D').asfreq()
df_daily
# Out:
#             Colorado     Texas  Ne w York      Ohio
# 2000-01-05  1.758510  0.374356   0.453846  1.746002
# 2000-01-06       NaN       NaN        NaN       NaN
# 2000-01-07       NaN       NaN        NaN       NaN
# 2000-01-08       NaN       NaN        NaN       NaN
# 2000-01-09       NaN       NaN        NaN       NaN
# 2000-01-10       NaN       NaN        NaN       NaN
# 2000-01-11       NaN       NaN        NaN       NaN
# 2000-01-12  0.686212  0.229502  -0.146142  1.221014

# %%
frame.resample('D').ffill()
# Out:
#             Colorado     Texas  Ne w York      Ohio
# 2000-01-05  1.758510  0.374356   0.453846  1.746002
# 2000-01-06  1.758510  0.374356   0.453846  1.746002
# 2000-01-07  1.758510  0.374356   0.453846  1.746002
# 2000-01-08  1.758510  0.374356   0.453846  1.746002
# 2000-01-09  1.758510  0.374356   0.453846  1.746002
# 2000-01-10  1.758510  0.374356   0.453846  1.746002
# 2000-01-11  1.758510  0.374356   0.453846  1.746002
# 2000-01-12  0.686212  0.229502  -0.146142  1.221014

# %%
frame.resample('D').ffill(limit=2)
# Out:
#             Colorado     Texas  Ne w York      Ohio
# 2000-01-05  1.758510  0.374356   0.453846  1.746002
# 2000-01-06  1.758510  0.374356   0.453846  1.746002
# 2000-01-07  1.758510  0.374356   0.453846  1.746002
# 2000-01-08       NaN       NaN        NaN       NaN
# 2000-01-09       NaN       NaN        NaN       NaN
# 2000-01-10       NaN       NaN        NaN       NaN
# 2000-01-11       NaN       NaN        NaN       NaN
# 2000-01-12  0.686212  0.229502  -0.146142  1.221014

# %%
frame.resample('W-THU').ffill()
# Out:
#             Colorado     Texas  Ne w York      Ohio
# 2000-01-06  1.758510  0.374356   0.453846  1.746002
# 2000-01-13  0.686212  0.229502  -0.146142  1.221014

# %%
frame = pd.DataFrame(np.random.randn(24, 4),
                     index=pd.period_range('1-2000', ' 12-2001',freq='M'),
                     columns=['Colorado', 'Texas', 'Ne w York', 'Ohio'])
frame[:5]
# Out:
#          Colorado     Texas  Ne w York      Ohio
# 2000-01 -0.885082 -1.969688  -2.559887  0.394156
# 2000-02 -0.611035 -0.054457   1.458970  0.753152
# 2000-03 -0.581098  1.561714   0.200732  0.618637
# 2000-04  1.255610  1.219653   0.704281 -1.717017
# 2000-05  0.379145 -0.361723  -1.787919 -0.453257

# %%
annual_frame = frame.resample('A-DEC').mean()
annual_frame
# Out:
#       Colorado     Texas  Ne w York      Ohio
# 2000  0.100492 -0.376217  -0.316650  0.144333
# 2001 -0.082118  0.179900   0.042856  0.209635

# %%
annual_frame.resample('Q-DEC').ffill() # Q-DEC: Quarterly, year ending in December
# Out:
#         Colorado     Texas  Ne w York      Ohio
# 2000Q1  0.100492 -0.376217  -0.316650  0.144333
# 2000Q2  0.100492 -0.376217  -0.316650  0.144333
# 2000Q3  0.100492 -0.376217  -0.316650  0.144333
# 2000Q4  0.100492 -0.376217  -0.316650  0.144333
# 2001Q1 -0.082118  0.179900   0.042856  0.209635
# 2001Q2 -0.082118  0.179900   0.042856  0.209635
# 2001Q3 -0.082118  0.179900   0.042856  0.209635
# 2001Q4 -0.082118  0.179900   0.042856  0.209635

# %%
annual_frame.resample('Q-DEC', convention='end').ffill ()
# Out:
#         Colorado     Texas  Ne w York      Ohio
# 2000Q4  0.100492 -0.376217  -0.316650  0.144333
# 2001Q1  0.100492 -0.376217  -0.316650  0.144333
# 2001Q2  0.100492 -0.376217  -0.316650  0.144333
# 2001Q3  0.100492 -0.376217  -0.316650  0.144333
# 2001Q4 -0.082118  0.179900   0.042856  0.209635

# %%
annual_frame.resample('Q-MAR').ffill() #由Q-MAR定义的时间区间只能升采样为A-MAR、A-JUN、A-SEP、A-DEC 等:
# Out:
#         Colorado     Texas  Ne w York      Ohio
# 2000Q4  0.100492 -0.376217  -0.316650  0.144333
# 2001Q1  0.100492 -0.376217  -0.316650  0.144333
# 2001Q2  0.100492 -0.376217  -0.316650  0.144333
# 2001Q3  0.100492 -0.376217  -0.316650  0.144333
# 2001Q4 -0.082118  0.179900   0.042856  0.209635
# 2002Q1 -0.082118  0.179900   0.042856  0.209635
# 2002Q2 -0.082118  0.179900   0.042856  0.209635
# 2002Q3 -0.082118  0.179900   0.042856  0.209635

# %% [markdown]
# ## 移动窗口函数

# %%
close_px_all = pd.read_csv('./stock_px.csv',parse_dates=True, index_col= 0)
close_px_all
# Out:
#                AA    AAPL     GE     IBM    JNJ   MSFT    PEP      SPX    XOM
# 1990-02-01   4.98    7.86   2.87   16.79   4.27   0.51   6.04   328.79   6.12
# 1990-02-02   5.04    8.00   2.87   16.89   4.37   0.51   6.09   330.92   6.24
# 1990-02-05   5.07    8.18   2.87   17.32   4.34   0.51   6.05   331.85   6.25
# 1990-02-06   5.01    8.12   2.88   17.56   4.32   0.51   6.15   329.66   6.23
# 1990-02-07   5.04    7.77   2.91   17.93   4.38   0.51   6.17   333.75   6.33
# ...           ...     ...    ...     ...    ...    ...    ...      ...    ...
# 2011-10-10  10.09  388.81  16.14  186.62  64.43  26.94  61.87  1194.89  76.28
# 2011-10-11  10.30  400.29  16.14  185.00  63.96  27.00  60.95  1195.54  76.27
# 2011-10-12  10.05  402.19  16.40  186.12  64.33  26.96  62.70  1207.25  77.16
# 2011-10-13  10.10  408.43  16.22  186.82  64.23  27.18  62.36  1203.66  76.37
# 2011-10-14  10.26  422.00  16.60  190.53  64.72  27.27  62.24  1224.58  78.11
#
# [5472 rows x 9 columns]

# %%
close_px = close_px_all[['AAPL', 'MSFT', 'XOM']]

# %%
close_px = close_px.resample('B').ffill()

# %%
close_px
# Out:
#               AAPL   MSFT    XOM
# 1990-02-01    7.86   0.51   6.12
# 1990-02-02    8.00   0.51   6.24
# 1990-02-05    8.18   0.51   6.25
# 1990-02-06    8.12   0.51   6.23
# 1990-02-07    7.77   0.51   6.33
# ...            ...    ...    ...
# 2011-10-10  388.81  26.94  76.28
# 2011-10-11  400.29  27.00  76.27
# 2011-10-12  402.19  26.96  77.16
# 2011-10-13  408.43  27.18  76.37
# 2011-10-14  422.00  27.27  78.11
#
# [5662 rows x 3 columns]

# %%
close_px.AAPL.plot()

# %%
close_px.AAPL.rolling(250).mean().plot() 
#表达式rolling(250)与groupby很像,但不是对其进行分组,
# 而是创建一个按照250天分组的滑动窗口对象
# rolling函数需要窗口中所有的值为非NA值。

# %%
appl_std250 = close_px.AAPL.rolling(250, min_periods=10 ).std()
appl_std250[5:12]
# Out:
# 1990-02-08         NaN
# 1990-02-09         NaN
# 1990-02-12         NaN
# 1990-02-13         NaN
# 1990-02-14    0.148189
# 1990-02-15    0.141003
# 1990-02-16    0.135454
# Freq: B, Name: AAPL, dtype: float64

# %%
appl_std250.plot()

# %% [markdown]
# 要计算扩展窗口平均(expanding window mean),可以使用expanding而不是rolling。“扩展”意味着,从时间序列的起始处开始窗口,增加窗口直到它超过所有的序列。

# %%
expanding_mean = appl_std250.expanding().mean()
expanding_mean
# Out:
# 1990-02-01         NaN
# 1990-02-02         NaN
# 1990-02-05         NaN
# 1990-02-06         NaN
# 1990-02-07         NaN
#                 ...
# 2011-10-10    8.817565
# 2011-10-11    8.820522
# 2011-10-12    8.823495
# 2011-10-13    8.826492
# 2011-10-14    8.829528
# Freq: B, Name: AAPL, Length: 5662, dtype: float64

# %%
close_px.rolling(60).mean().plot(logy=True)

# %%
close_px.rolling('20D').mean() 
#rolling函数也可以接受一个指定固定大小时间补偿字符串,而不是一组时期。
# 这样可以方便处理不规律的时间序列。这些字符串也可以传递给resample。
# Out:
#                   AAPL       MSFT        XOM
# 1990-02-01    7.860000   0.510000   6.120000
# 1990-02-02    7.930000   0.510000   6.180000
# 1990-02-05    8.013333   0.510000   6.203333
# 1990-02-06    8.040000   0.510000   6.210000
# 1990-02-07    7.986000   0.510000   6.234000
# ...                ...        ...        ...
# 2011-10-10  389.351429  25.602143  72.527857
# 2011-10-11  388.505000  25.674286  72.835000
# 2011-10-12  388.531429  25.810000  73.400714
# 2011-10-13  388.826429  25.961429  73.905000
# 2011-10-14  391.038000  26.048667  74.185333
#
# [5662 rows x 3 columns]

# %% [markdown]
# 除了rolling和expanding,pandas还有ewm运算符。下面这个例子对比了苹果公司股价的30日移动平均和span=30的指数加权移动平均

# %%
aapl_px = close_px.AAPL['2006':'2007']

# %%
ma60 = aapl_px.rolling(30, min_periods=20).mean()

# %%
ewma60 = aapl_px.ewm(span=30).mean()

# %%
ma60.plot(style='k--', label='Simple MA')
ewma60.plot(style='k-', label='EW MA')
plt.legend()

# %% [markdown]
# ### 二元移动窗口函数

# %% [markdown]
# 有些统计运算(如相关系数和协方差)需要在两个时间序列上执行。

# %%
spx_px = close_px_all['SPX']
spx_rets = spx_px.pct_change()
returns = close_px.pct_change()

# %%
corr = returns.AAPL.rolling(125, min_periods=100).corr (spx_rets) #corr聚合函数开始计算与spx_rets滚动相关系数

# %%
corr.plot()

# %%
corr = returns.rolling(125, min_periods=100).corr(spx_rets)
corr.plot()

# %% [markdown]
# ### 用户定义的移动窗口函数

# %% [markdown]
# rolling_apply函数使你能够在移动窗口上应用自己设计的数组函数。唯一要求的就是:该函数要能从数组的各个片段中产生单个值(即约简)。

# %%
from scipy.stats import percentileofscore

# %%
score_at_2percent = lambda x: percentileofscore(x, 0.02 ) #样本分位数

# %%
result = returns.AAPL.rolling(250).apply(score_at_2percent)
result.plot()

# %% [markdown]
# ## pandas的分类类型

# %%
fruits = ['apple', 'orange', 'apple', 'apple'] * 2

# %%
N = len(fruits)

# %%
df = pd.DataFrame({'fruit': fruits,'basket_id': np.arange(N),
                   'count': np.random.randint(3, 15, size=N),
                   'weight': np.random.uniform(0, 4, size=N)},
                  columns=['basket_id', 'fruit', 'count' , 'weight'])
df
# Out:
#    basket_id   fruit  count    weight
# 0          0   apple      6  1.761165
# 1          1  orange      9  0.763878
# 2          2   apple      8  3.510009
# 3          3   apple     11  1.582837
# 4          4   apple      8  3.807799
# 5          5  orange     10  3.728699
# 6          6   apple      3  1.245050
# 7          7   apple      5  3.427563

# %%
fruit_cat = df['fruit'].astype('category')

# %%
fruit_cat
# Out:
# 0     apple
# 1    orange
# 2     apple
# 3     apple
# 4     apple
# 5    orange
# 6     apple
# 7     apple
# Name: fruit, dtype: category
# Categories (2, object): [apple, orange]

# %%
c = fruit_cat.values
c
# Out:
# [apple, orange, apple, apple, apple, orange, apple, apple]
# Categories (2, object): [apple, orange]

# %% [markdown]
# ### 分类对象有categories和codes属性:

# %%
c.categories
# Out:
# Index(['apple', 'orange'], dtype='object')

# %%
c.codes
# Out:
# array([0, 1, 0, 0, 0, 1, 0, 0], dtype=int8)

# %%
df['fruit'] = df['fruit'].astype('category')

# %%
df.fruit
# Out:
# 0     apple
# 1    orange
# 2     apple
# 3     apple
# 4     apple
# 5    orange
# 6     apple
# 7     apple
# Name: fruit, dtype: category
# Categories (2, object): [apple, orange]

# %%
my_categories = pd.Categorical(['foo', 'bar', 'baz', 'f oo', 'bar'])
# 从其它Python序列直接创建pandas.Categorical

# %%
my_categories
# Out:
# [foo, bar, baz, f oo, bar]
# Categories (4, object): [bar, baz, f oo, foo]

# %%
categories = ['foo', 'bar', 'baz']
codes = [0, 1, 2, 0, 0, 1]
my_cats_2 = pd.Categorical.from_codes(codes, categories )

# %%
my_cats_2
# Out:
# [foo, bar, baz, foo, foo, bar]
# Categories (3, object): [foo, bar, baz]

# %% [markdown]
# # Python 建模库介绍

# %% [markdown]
# pandas与其它分析库通常是靠NumPy的数组联系起来的。将DataFrame转换为NumPy数组,可以使用.values属性

# %%
data = pd.DataFrame({
'x0': [1, 2, 3, 4, 5],
'x1': [0.01, -0.01, 0.25, -4.1, 0.],
'y': [-1.5, 0., 3.6, 1.3, -2.]})
data
# Out:
#    x0    x1    y
# 0   1  0.01 -1.5
# 1   2 -0.01  0.0
# 2   3  0.25  3.6
# 3   4 -4.10  1.3
# 4   5  0.00 -2.0

# %%
data.values
# Out:
# array([[ 1.  ,  0.01, -1.5 ],
#        [ 2.  , -0.01,  0.  ],
#        [ 3.  ,  0.25,  3.6 ],
#        [ 4.  , -4.1 ,  1.3 ],
#        [ 5.  ,  0.  , -2.  ]])

# %%
df2 = pd.DataFrame(data.values, columns=['one', 'two', 'three'])
df2
# Out:
#    one   two  three
# 0  1.0  0.01   -1.5
# 1  2.0 -0.01    0.0
# 2  3.0  0.25    3.6
# 3  4.0 -4.10    1.3
# 4  5.0  0.00   -2.0

# %%
df3 = data.copy()

# %%
df3['strings'] = ['a', 'b', 'c', 'd', 'e']

# %%
df3.values
# Out:
# array([[1, 0.01, -1.5, 'a'],
#        [2, -0.01, 0.0, 'b'],
#        [3, 0.25, 3.6, 'c'],
#        [4, -4.1, 1.3, 'd'],
#        [5, 0.0, -2.0, 'e']], dtype=object)

# %%
model_cols = ['x0', 'x1']

# %%
data.loc[:, model_cols].values
# Out:
# array([[ 1.  ,  0.01],
#        [ 2.  , -0.01],
#        [ 3.  ,  0.25],
#        [ 4.  , -4.1 ],
#        [ 5.  ,  0.  ]])

# %%
data['category'] = pd.Categorical(['a', 'b', 'a', 'a', 'b'],categories=['a', 'b'] )

# %%
data
# Out:
#    x0    x1    y category
# 0   1  0.01 -1.5        a
# 1   2 -0.01  0.0        b
# 2   3  0.25  3.6        a
# 3   4 -4.10  1.3        a
# 4   5  0.00 -2.0        b

# %%
dummies = pd.get_dummies(data.category, prefix='categor y')

# %%
data_with_dummies = data.drop('category', axis=1).join( dummies)

# %%
data_with_dummies
# Out:
#    x0    x1    y  categor y_a  categor y_b
# 0   1  0.01 -1.5            1            0
# 1   2 -0.01  0.0            0            1
# 2   3  0.25  3.6            1            0
# 3   4 -4.10  1.3            1            0
# 4   5  0.00 -2.0            0            1

# %% [markdown]
# ## 用Patsy创建模型描述

# %% [markdown]
# Patsy是Python的一个库,使用简短的字符串“公式语法”描述统计模型(尤其是线性模型)

# %% [markdown]
# 利用Patsy创建模型描述 Patsy是一个python库，用于描述统计模型（尤其是线性模型），方法是通过一个叫做公式语法（formula syntax）的字符串来描述。这种公式语法的灵感来源于R和S语言中的公式语法。 Patsy的公式是有特殊格式的字符串，像下面这样： y ~ x0 + x1 这种a + b的语法并不代表将a和b相加，而是代表为模型创建的设计矩阵的术语（terms in the design matrix）。

# %%
import patsy

# %%
data = pd.DataFrame({
'x0': [1, 2, 3, 4, 5],
'x1': [0.01, -0.01, 0.25, -4.1, 0.],
'y': [-1.5, 0., 3.6, 1.3, -2.]})
data
# Out:
#    x0    x1    y
# 0   1  0.01 -1.5
# 1   2 -0.01  0.0
# 2   3  0.25  3.6
# 3   4 -4.10  1.3
# 4   5  0.00 -2.0

# %%
y, X = patsy.dmatrices('y ~ x0 + x1', data)

# %%
y
# Out:
# DesignMatrix with shape (5, 1)
#      y
#   -1.5
#    0.0
#    3.6
#    1.3
#   -2.0
#   Terms:
#     'y' (column 0)

# %%
X
# Out:
# DesignMatrix with shape (5, 3)
#   Intercept  x0     x1
#           1   1   0.01
#           1   2  -0.01
#           1   3   0.25
#           1   4  -4.10
#           1   5   0.00
#   Terms:
#     'Intercept' (column 0)
#     'x0' (column 1)
#     'x1' (column 2)

# %%
np.asarray(y)
# Out:
# array([[-1.5],
#        [ 0. ],
#        [ 3.6],
#        [ 1.3],
#        [-2. ]])

# %%
np.asarray(X)
# Out:
# array([[ 1.  ,  1.  ,  0.01],
#        [ 1.  ,  2.  , -0.01],
#        [ 1.  ,  3.  ,  0.25],
#        [ 1.  ,  4.  , -4.1 ],
#        [ 1.  ,  5.  ,  0.  ]])

# %%
patsy.dmatrices('y ~ x0 + x1 + 0', data)[1] #添加 +0 到模型可以不显示intercept
# Out:
# DesignMatrix with shape (5, 2)
#   x0     x1
#    1   0.01
#    2  -0.01
#    3   0.25
#    4  -4.10
#    5   0.00
#   Terms:
#     'x0' (column 0)
#     'x1' (column 1)

# %% [markdown]
# Patsy对象可以直接传递到算法(比如numpy.linalg.lstsq)中,它执行普通最小二乘回归:

# %%
coef, resid, _, _ = np.linalg.lstsq(X, y)
# Out:
# /Users/mac/.pyenv/versions/3.7.3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """Entry point for launching an IPython kernel.

# %%
coef
# Out:
# array([[ 0.31290976],
#        [-0.07910564],
#        [-0.26546384]])

# %%
coef = pd.Series(coef.squeeze(), index=X.design_info.column_names)
coef
# Out:
# Intercept    0.312910
# x0          -0.079106
# x1          -0.265464
# dtype: float64

# %%
y, X = patsy.dmatrices('y ~ x0 + np.log(np.abs(x1) + 1)' , data)

# %%
X
# Out:
# DesignMatrix with shape (5, 3)
#   Intercept  x0  np.log(np.abs(x1) + 1)
#           1   1                 0.00995
#           1   2                 0.00995
#           1   3                 0.22314
#           1   4                 1.62924
#           1   5                 0.00000
#   Terms:
#     'Intercept' (column 0)
#     'x0' (column 1)
#     'np.log(np.abs(x1) + 1)' (column 2)

# %%
y, X = patsy.dmatrices('y ~ standardize(x0) + center(x1 )', data)
X
# Out:
# DesignMatrix with shape (5, 3)
#   Intercept  standardize(x0)  center(x1)
#           1         -1.41421        0.78
#           1         -0.70711        0.76
#           1          0.00000        1.02
#           1          0.70711       -3.33
#           1          1.41421        0.77
#   Terms:
#     'Intercept' (column 0)
#     'standardize(x0)' (column 1)
#     'center(x1)' (column 2)

# %%
import statsmodels.api as sm 
import statsmodels.formula.api as smf

# %%
def dnorm(mean, variance, size=1):
    if isinstance(size, int):         
        size = size,     
        return mean + np.sqrt(variance) * np.random.randn(*size) 
# For reproducibility 
np.random.seed(12345) 
N = 100 
X = np.c_[dnorm(0, 0.4, size=N),dnorm(0, 0.6, size=N),dnorm(0, 0.2, size=N)] 
eps = dnorm(0, 0.1, size=N) 
beta = [0.1, 0.3, 0.5] 
y = np.dot(X, beta) + eps

# %%
X_model = sm.add_constant(X)

# %%
model = sm.OLS(y, X)

# %%
results = model.fit()

# %%
results.params
# Out:
# array([ 0.28      , -0.11187227, -0.26546384])

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                 -0.915
# Method:                 Least Squares   F-statistic:                   0.04431
# Date:                Sun, 08 Mar 2020   Prob (F-statistic):              0.958
# Time:                        15:22:48   Log-Likelihood:                -10.515
# No. Observations:                   5   AIC:                             27.03
# Df Residuals:                       2   BIC:                             25.86
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.2800      1.401      0.200      0.860      -5.750       6.310
# ...

# %%
data = pd.DataFrame(X, columns=['col0', 'col1', 'col2'] )

# %%
data['y'] = y

# %%
results = smf.ols('y ~ col0 + col1 + col2', data=data).fit()

# %%
results.params
# Out:
# Intercept    0.140000
# col0         0.140000
# col1        -0.111872
# col2        -0.265464
# dtype: float64

# %%
results.tvalues
# Out:
# Intercept    0.199807
# col0         0.199807
# col1        -0.074827
# col2        -0.296135
# dtype: float64

# %%
results.predict(data[:5])
# Out:
# 0    0.231149
# 1    0.157353
# 2    0.009227
# 3    1.084889
# 4   -0.082618
# dtype: float64

# %% [markdown]
# statsmodels的另一模型类是进行时间序列分析,包括自回归过程、卡尔曼滤波和其它态空间模型,和多元自回归模型。

# %%
init_x = 4 
import random 
values = [init_x, init_x] 
N = 1000 
b0 = 0.8 
b1 = -0.4 
noise = dnorm(0, 0.1, N) 
for i in range(N):     
    new_x = values[-1] * b0 + values[-2] * b1 + noise[i]     
    values.append(new_x)
#  这个数据有AR(2)结构(两个延迟),参数是0.8和-0.4。

# %%
MAXLAGS = 5

# %%
model = sm.tsa.AR(values)
# Out:
# /Users/mac/.pyenv/versions/3.7.3/lib/python3.7/site-packages/statsmodels/tsa/ar_model.py:691: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
# ...

# %%
results = model.fit(MAXLAGS)

# %%
results.params
# Out:
# array([-0.00616093,  0.78446347, -0.40847891, -0.01364148,  0.01496872,
#         0.01429462])
