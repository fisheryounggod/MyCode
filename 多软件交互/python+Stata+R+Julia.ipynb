# %%
import ipystata

# %%
# %%stata -o df
# use /Users/mac/Stata/chenqiang/grilic.dta,clear
# describe
# sum
# Out:
# Contains data from /Users/mac/Stata/chenqiang/grilic.dta
#   obs:           758
#  vars:            12                          1 Feb 2016 09:25
#  size:        16,676
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#               storage   display    value
# variable name   type    format     label      variable label
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# rns             byte    %8.0g                 south = 1
# mrt             byte    %8.0g                 married = 1
# smsa            byte    %8.0g                 big cities =1
# med             byte    %8.0g                 mother's education
# iq              int     %8.0g                 IQ
# ...

# %%
df.describe()
# Out:
#               rns         mrt        smsa        med          iq         kww  \
# count  758.000000  758.000000  758.000000  758.00000  758.000000  758.000000
# mean     0.269129    0.514512    0.704485   10.91029  103.856201   36.573879
# std      0.443800    0.500119    0.456575    2.74112   13.618666    7.302247
# min      0.000000    0.000000    0.000000    0.00000   54.000000   12.000000
# 25%      0.000000    0.000000    0.000000    9.00000   95.250000   32.000000
# 50%      0.000000    1.000000    1.000000   12.00000  104.000000   37.000000
# 75%      1.000000    1.000000    1.000000   12.00000  113.750000   41.000000
# max      1.000000    1.000000    1.000000   18.00000  145.000000   56.000000
#
#               age           s        expr      tenure         lnw         wage
# count  758.000000  758.000000  758.000000  758.000000  758.000000   758.000000
# mean    21.835092   13.405013    1.735429    1.831135    5.686738   323.916138
# ...

# %%
# %%stata
# sum lnw,detail
# Out:
# no variables defined
# r(111);
#
# end of do-file
# r(111);
